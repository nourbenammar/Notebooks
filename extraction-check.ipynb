# %%
pip install paddlepaddle paddleocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 4.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.0/195.0 MB 7.6 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 25.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.4 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 441.6/441.6 kB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 5.3 MB/s eta 0:00:00
# ...

# %%
pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.5 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.8 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00:00:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.8 MB/s eta 0:00:00:00:0100:01
# Note: you may need to restart the kernel to use updated packages.

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(
    text_recognition_model_name="PP-OCRv5_server_rec",
    ocr_version="PP-OCRv5",
    use_doc_orientation_classify=True,
    use_doc_unwarping=True,
    use_textline_orientation=True,
)

result = ocr.predict("/kaggle/input/chequestest/00006810107000811070118593005R.JPG")
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")
# Out:
# /tmp/ipykernel_35/554416558.py:3: UserWarning: `lang` and `ocr_version` will be ignored when model names or model directories are not `None`.
#   ocr = PaddleOCR(
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:715: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /root/.paddlex/official_models.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# inference.json: 0.00B [00:00, ?B/s]
# inference.yml:   0%|          | 0.00/766 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# ...

# %%
from together import Together
import os
import json

# Set Together API key
os.environ["TOGETHER_API_KEY"] = "e17e5d915a1789dbe83e8b36df3714ae06de0818d92af213dc7bb556a078e120"
client = Together(api_key=os.environ["TOGETHER_API_KEY"])

# OCR result as text lines (from PaddleOCR)
ocr_lines = [
    '', 'BPDX300.000', 'Cheque N* 0000681', 'ATB Arab Tanisian Bank', 
    'PAYEZCONTRECECHEQUENONENDOSSABLE', 'La', '', '', 'aufauprofiduebqueoudunoreald',
    "Al'ordrede", 'Peysle', 'TULAIREDUCOMPESL', 'soug ge', '01070008110701185930TND', 
    '42 Bis Av.Bab Bnet', 'TEL:71568130', '224/6', 'A', ''
]

# Bank code → bank name mapping
bank_code_table = """
00  BCT     
01  ATB     
02  BFT     
03  BNA     
04  ATTIJARI
05  BT      
07  AMEN BANK
08  BIAT    
09  BDET    
10  STB     
11  UBCI    
12  UIB     
13  P.T.T   
14  BH      
15  T.L     
16  CBNA    
17  C.C.P.  
18  BNDT    
20  BTK     
21  STUSID  
22  BCMA    
23  BTQI    
24  BTE     
25  BZ      
26  BTL     
27  B.T.S   
28  ABC     
29  CIL     
30  COTUNC  
31  BCMA    
32  BEST    
33  NAIB    
34  TAAB    
35  ALUBAF  
36  TL      
37  UTL     
47  WIB     
51  TRT     
52  CENT    
66  CMCAT   
71  BOA     
72  UTB     
73  TIB     
74  LINC    
75  CITIB   
78  ABC     
80  CNSS    
81  AIL     
84  PAYVAGO
"""

# Format OCR lines for prompt
ocr_text_block = json.dumps(ocr_lines, indent=2)

# Create the prompt with validation instructions
prompt = f"""
You are a document parser and OCR correction assistant.

Given the following OCR-extracted lines from a cheque scan:

{ocr_text_block}

Your task is to:
1. Correct spelling and recognition mistakes (e.g., fix names like "Amab Tunisian" → "Arab Tunisian").
2. Extract the following fields:
   - **rib**: a single 20-digit number (remove "TND", spaces, etc).
   - **cheque_reference**: exactly a 7-digit number, ignore any prefix like "Cheque N".
   - **bank_code**: the first two digits of the RIB.
   - **bank_name**: infer from the bank_code using the table below.
   - **bank_info**: include location/address/phone lines from the OCR.

Use this official list to match bank_code to bank_name:

{bank_code_table}

Return the final result as JSON with the keys:
- "rib"
- "cheque_reference"
- "bank_code"
- "bank_name"
- "bank_info"

Make sure all values are clean and corrected.
"""

# Call Together's LLaMA-4 model
response = client.chat.completions.create(
    model="meta-llama/Llama-4-Scout-17B-16E-Instruct",
    messages=[
        {"role": "system", "content": "You are a document parser and field extractor specialized in correcting OCR output."},
        {"role": "user", "content": prompt}
    ],
    temperature=0.2,
    max_tokens=512,
)

# Show the cleaned JSON result
print("\n✅ Extracted & Corrected Result:")
print(response.choices[0].message.content)
