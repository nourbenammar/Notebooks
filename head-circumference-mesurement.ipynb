# %% [markdown]
# # Fetal Head Circumference Measurement

# %% [markdown]
# In this notebook, we focused on measuring head circumference (HC) using a dataset from the HC18 Grand Challenge. We applied a lightweight deep learning model to perform image segmentation on two-dimensional ultrasound images of fetal heads. This model was designed to achieve both fast and accurate segmentation, which is then used to calculate the fetal HC. Our method provides a reliable and efficient way for obstetricians to measure fetal HC with high accuracy, even in environments with limited computing resources. The evaluation metrics demonstrated that our approach offers precise boundary predictions and high overlap with the ground truth, making it a valuable tool for clinical practice.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
import time
import os
import numpy as np
import pandas as pd
import cv2
from sklearn.linear_model import LinearRegression
import shutil
import random

# %% [markdown]
# # DATA PREPROCESSING

# %%
def img_crop(in_img, crop_size=[512,768]):
    """
    Crop an image to a specific size.
    """

    crop_img = np.zeros([512,768],dtype=in_img.dtype)

    r_out = crop_size[0]
    c_out = crop_size[1]

    r_in, c_in = in_img.shape

    dr = int((r_in - r_out) / 2 + 0.5)
    dc = int((c_in - c_out) / 2 + 0.5)

    if dr > 0:
        rp_in = [dr,dr+r_out]
        rp_out = [0, r_out]
    else:
        dr = -dr
        rp_in = [0,r_in]
        rp_out = [dr,dr+r_in]

    if dc > 0:
        cp_in = [dc,dc+c_out]
        cp_out = [0, c_out]
    else:
        dc = -dc
        cp_in = [0,c_in]
        cp_out = [dc,dc+c_in]

    crop_img[rp_out[0]:rp_out[1],cp_out[0]:cp_out[1]] = in_img[rp_in[0]:rp_in[1],cp_in[0]:cp_in[1]]

    return crop_img

# %%
def ellip_fill(in_folder, out_folder):

    dirs = os.listdir(in_folder)
    for i in range(len(dirs)):
        print('Ellip filling: %d / %d' % (i + 1, len(dirs)))
        img_name = dirs[i]
        img_path = in_folder + img_name

        img = cv2.imread(img_path, 0)

        img = 255 - img
        retval, labels, stats, centroids = cv2.connectedComponentsWithStats(img, connectivity=4)
        ellipse = labels == 2
        ellipse = ellipse * 255
        ellipse = ellipse.astype('uint8')

        # Original label is 3 pixels wide so an expansion process is needed
        kernel = np.ones((3, 3), np.uint8)
        ellipse = cv2.dilate(ellipse, kernel, iterations=1)

        # Save
        save_path = out_folder + img_name
        cv2.imwrite(save_path, ellipse)

# %%
def img_augumentation(in_folder, out_folder, data):
    """
    Data augumentation, operations include rotation of 10, 20 and 30 degrees in clockwise and counterclockwise,
    magnification of 1.15 times, narrowing of 0.85 times, left and right flip, up and down flip.
    """

    dirs = os.listdir(in_folder)
    for i in range(len(dirs)):
        print('%s augumentation: %d / %d' % (data, i + 1, len(dirs)))
        img_name = dirs[i]
        img_path = in_folder + img_name
        img = cv2.imread(img_path, 0)
        h,w = img.shape

        # Image scale
        matRotate_085 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), 0, 0.85)
        matRotate_115 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), 0, 1.15)

        img_085 = cv2.warpAffine(img, matRotate_085, (w, h))
        img_115 = cv2.warpAffine(img, matRotate_115, (w, h))

        # Flip
        img_Flr = cv2.flip(img, 1)  # flip left-right
        img_Fud = cv2.flip(img, 0)  # flip up-down

        # Rotate clockwise and counterclockwise
        matRotate_p10 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), 10, 1)
        matRotate_p20 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), 20, 1)
        matRotate_p30 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), 30, 1)
        matRotate_m10 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), -10, 1)
        matRotate_m20 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), -20, 1)
        matRotate_m30 = cv2.getRotationMatrix2D((w * 0.5, h * 0.5), -30, 1)

        img_Rp10 = cv2.warpAffine(img, matRotate_p10, (w, h))
        img_Rp20 = cv2.warpAffine(img, matRotate_p20, (w, h))
        img_Rp30 = cv2.warpAffine(img, matRotate_p30, (w, h))
        img_Rm10 = cv2.warpAffine(img, matRotate_m10, (w, h))
        img_Rm20 = cv2.warpAffine(img, matRotate_m20, (w, h))
        img_Rm30 = cv2.warpAffine(img, matRotate_m30, (w, h))

        # Image name
        if data=="image":
            img_085_name = img_name[:-4] + '_S.png'
            img_115_name = img_name[:-4] + '_L.png'
            img_Flr_name = img_name[:-4] + '_Flr.png'
            img_Fud_name = img_name[:-4] + '_Fud.png'
            img_Rp10_name = img_name[:-4] + '_Rp10.png'
            img_Rp20_name = img_name[:-4] + '_Rp20.png'
            img_Rp30_name = img_name[:-4] + '_Rp30.png'
            img_Rm10_name = img_name[:-4] + '_Rm10.png'
            img_Rm20_name = img_name[:-4] + '_Rm20.png'
            img_Rm30_name = img_name[:-4] + '_Rm30.png'
        elif data == "label":
            img_085_name = img_name[:-15] + '_S_Annotation.png'
            img_115_name = img_name[:-15] + '_L_Annotation.png'
            img_Flr_name = img_name[:-15] + '_Flr_Annotation.png'
            img_Fud_name = img_name[:-15] + '_Fud_Annotation.png'
            img_Rp10_name = img_name[:-15] + '_Rp10_Annotation.png'
            img_Rp20_name = img_name[:-15] + '_Rp20_Annotation.png'
            img_Rp30_name = img_name[:-15] + '_Rp30_Annotation.png'
            img_Rm10_name = img_name[:-15] + '_Rm10_Annotation.png'
            img_Rm20_name = img_name[:-15] + '_Rm20_Annotation.png'
            img_Rm30_name = img_name[:-15] + '_Rm30_Annotation.png'

        else:
            print("Image augumentation falied! Please set the input parameter 'data' to 'image' or 'label'!")
            break

        # Save path
        img_path = out_folder + img_name
        img_085_path = out_folder + img_085_name
        img_115_path = out_folder + img_115_name
        img_Flr_path = out_folder + img_Flr_name
        img_Fud_path = out_folder + img_Fud_name
        img_Rp10_path = out_folder + img_Rp10_name
        img_Rp20_path = out_folder + img_Rp20_name
        img_Rp30_path = out_folder + img_Rp30_name
        img_Rm10_path = out_folder + img_Rm10_name
        img_Rm20_path = out_folder + img_Rm20_name
        img_Rm30_path = out_folder + img_Rm30_name

        # Save results
        cv2.imwrite(img_path, img)
        cv2.imwrite(img_085_path, img_085)
        cv2.imwrite(img_115_path, img_115)
        cv2.imwrite(img_Flr_path, img_Flr)
        cv2.imwrite(img_Fud_path, img_Fud)
        cv2.imwrite(img_Rp10_path, img_Rp10)
        cv2.imwrite(img_Rp20_path, img_Rp20)
        cv2.imwrite(img_Rp30_path, img_Rp30)
        cv2.imwrite(img_Rm10_path, img_Rm10)
        cv2.imwrite(img_Rm20_path, img_Rm20)
        cv2.imwrite(img_Rm30_path, img_Rm30)

    print("Images augumentation finished!")

# %%
HC18_training_set_folder = '/kaggle/input/fetal-head/training_set/training_set/'

# To save preprocess images
train_img_folder = '/kaggle/working/data/train/images/'
os.makedirs(train_img_folder)

# To save preprocess labels
train_label_folder = '/kaggle/working/data/train/labels/'
os.makedirs(train_label_folder)

# %%
dirs = os.listdir(HC18_training_set_folder)
for i in range(len(dirs)):
    print("Dividing images and labels: %d / %d" % (i+1,len(dirs)))
    img_name = dirs[i]
    img_path = HC18_training_set_folder + img_name
    img = cv2.imread(img_path,0)
    
    if img is None:
        print(f"Error: Image not loaded. Please check the image path: {img_path}")
        continue
    # Crop images
    crop_img = img_crop(img)

    # Save images
    if img_name.endswith('Annotation.png'):
        save_path = os.path.join(train_label_folder, img_name)
    else:
        save_path = os.path.join(train_img_folder, img_name)

    cv2.imwrite(save_path, crop_img)
# Out:
# Dividing images and labels: 1 / 1999
# Dividing images and labels: 2 / 1999
# Dividing images and labels: 3 / 1999
# Dividing images and labels: 4 / 1999
# Dividing images and labels: 5 / 1999
# Dividing images and labels: 6 / 1999
# Dividing images and labels: 7 / 1999
# Dividing images and labels: 8 / 1999
# Dividing images and labels: 9 / 1999
# Dividing images and labels: 10 / 1999
# Dividing images and labels: 11 / 1999
# Dividing images and labels: 12 / 1999
# Dividing images and labels: 13 / 1999
# Dividing images and labels: 14 / 1999
# Dividing images and labels: 15 / 1999
# Dividing images and labels: 16 / 1999
# Dividing images and labels: 17 / 1999
# Dividing images and labels: 18 / 1999
# Dividing images and labels: 19 / 1999
# Dividing images and labels: 20 / 1999
# Dividing images and labels: 21 / 1999
# Dividing images and labels: 22 / 1999
# Dividing images and labels: 23 / 1999
# Dividing images and labels: 24 / 1999
# Dividing images and labels: 25 / 1999
# Dividing images and labels: 26 / 1999
# Dividing images and labels: 27 / 1999
# Dividing images and labels: 28 / 1999
# Dividing images and labels: 29 / 1999
# Dividing images and labels: 30 / 1999
# Dividing images and labels: 31 / 1999
# Dividing images and labels: 32 / 1999
# Dividing images and labels: 33 / 1999
# Dividing images and labels: 34 / 1999
# Dividing images and labels: 35 / 1999
# Dividing images and labels: 36 / 1999
# Dividing images and labels: 37 / 1999
# Dividing images and labels: 38 / 1999
# Dividing images and labels: 39 / 1999
# Dividing images and labels: 40 / 1999
# Dividing images and labels: 41 / 1999
# Dividing images and labels: 42 / 1999
# Dividing images and labels: 43 / 1999
# Dividing images and labels: 44 / 1999
# Dividing images and labels: 45 / 1999
# Dividing images and labels: 46 / 1999
# Dividing images and labels: 47 / 1999
# Dividing images and labels: 48 / 1999
# Dividing images and labels: 49 / 1999
# Dividing images and labels: 50 / 1999
# Dividing images and labels: 51 / 1999
# Dividing images and labels: 52 / 1999
# Dividing images and labels: 53 / 1999
# Dividing images and labels: 54 / 1999
# Dividing images and labels: 55 / 1999
# Dividing images and labels: 56 / 1999
# Dividing images and labels: 57 / 1999
# Dividing images and labels: 58 / 1999
# Dividing images and labels: 59 / 1999
# Dividing images and labels: 60 / 1999
# Dividing images and labels: 61 / 1999
# Dividing images and labels: 62 / 1999
# Dividing images and labels: 63 / 1999
# Dividing images and labels: 64 / 1999
# Dividing images and labels: 65 / 1999
# Dividing images and labels: 66 / 1999
# Dividing images and labels: 67 / 1999
# Dividing images and labels: 68 / 1999
# Dividing images and labels: 69 / 1999
# Dividing images and labels: 70 / 1999
# Dividing images and labels: 71 / 1999
# Dividing images and labels: 72 / 1999
# Dividing images and labels: 73 / 1999
# Dividing images and labels: 74 / 1999
# Dividing images and labels: 75 / 1999
# Dividing images and labels: 76 / 1999
# Dividing images and labels: 77 / 1999
# Dividing images and labels: 78 / 1999
# Dividing images and labels: 79 / 1999
# Dividing images and labels: 80 / 1999
# Dividing images and labels: 81 / 1999
# Dividing images and labels: 82 / 1999
# Dividing images and labels: 83 / 1999
# Dividing images and labels: 84 / 1999
# Dividing images and labels: 85 / 1999
# Dividing images and labels: 86 / 1999
# Dividing images and labels: 87 / 1999
# Dividing images and labels: 88 / 1999
# Dividing images and labels: 89 / 1999
# Dividing images and labels: 90 / 1999
# Dividing images and labels: 91 / 1999
# Dividing images and labels: 92 / 1999
# Dividing images and labels: 93 / 1999
# Dividing images and labels: 94 / 1999
# Dividing images and labels: 95 / 1999
# Dividing images and labels: 96 / 1999
# Dividing images and labels: 97 / 1999
# Dividing images and labels: 98 / 1999
# Dividing images and labels: 99 / 1999
# Dividing images and labels: 100 / 1999
# Dividing images and labels: 101 / 1999
# Dividing images and labels: 102 / 1999
# Dividing images and labels: 103 / 1999
# Dividing images and labels: 104 / 1999
# Dividing images and labels: 105 / 1999
# Dividing images and labels: 106 / 1999
# Dividing images and labels: 107 / 1999
# Dividing images and labels: 108 / 1999
# Dividing images and labels: 109 / 1999
# Dividing images and labels: 110 / 1999
# Dividing images and labels: 111 / 1999
# Dividing images and labels: 112 / 1999
# Dividing images and labels: 113 / 1999
# Dividing images and labels: 114 / 1999
# Dividing images and labels: 115 / 1999
# Dividing images and labels: 116 / 1999
# Dividing images and labels: 117 / 1999
# Dividing images and labels: 118 / 1999
# Dividing images and labels: 119 / 1999
# Dividing images and labels: 120 / 1999
# Dividing images and labels: 121 / 1999
# Dividing images and labels: 122 / 1999
# Dividing images and labels: 123 / 1999
# Dividing images and labels: 124 / 1999
# Dividing images and labels: 125 / 1999
# Dividing images and labels: 126 / 1999
# Dividing images and labels: 127 / 1999
# Dividing images and labels: 128 / 1999
# Dividing images and labels: 129 / 1999
# Dividing images and labels: 130 / 1999
# Dividing images and labels: 131 / 1999
# Dividing images and labels: 132 / 1999
# Dividing images and labels: 133 / 1999
# Dividing images and labels: 134 / 1999
# Dividing images and labels: 135 / 1999
# Dividing images and labels: 136 / 1999
# Dividing images and labels: 137 / 1999
# Dividing images and labels: 138 / 1999
# Dividing images and labels: 139 / 1999
# Dividing images and labels: 140 / 1999
# Dividing images and labels: 141 / 1999
# Dividing images and labels: 142 / 1999
# Dividing images and labels: 143 / 1999
# Dividing images and labels: 144 / 1999
# Dividing images and labels: 145 / 1999
# Dividing images and labels: 146 / 1999
# Dividing images and labels: 147 / 1999
# Dividing images and labels: 148 / 1999
# Dividing images and labels: 149 / 1999
# Dividing images and labels: 150 / 1999
# Dividing images and labels: 151 / 1999
# Dividing images and labels: 152 / 1999
# Dividing images and labels: 153 / 1999
# Dividing images and labels: 154 / 1999
# Dividing images and labels: 155 / 1999
# Dividing images and labels: 156 / 1999
# Dividing images and labels: 157 / 1999
# Dividing images and labels: 158 / 1999
# Dividing images and labels: 159 / 1999
# Dividing images and labels: 160 / 1999
# Dividing images and labels: 161 / 1999
# Dividing images and labels: 162 / 1999
# Dividing images and labels: 163 / 1999
# Dividing images and labels: 164 / 1999
# Dividing images and labels: 165 / 1999
# Dividing images and labels: 166 / 1999
# Dividing images and labels: 167 / 1999
# Dividing images and labels: 168 / 1999
# Dividing images and labels: 169 / 1999
# Dividing images and labels: 170 / 1999
# Dividing images and labels: 171 / 1999
# Dividing images and labels: 172 / 1999
# Dividing images and labels: 173 / 1999
# Dividing images and labels: 174 / 1999
# Dividing images and labels: 175 / 1999
# Dividing images and labels: 176 / 1999
# Dividing images and labels: 177 / 1999
# Dividing images and labels: 178 / 1999
# Dividing images and labels: 179 / 1999
# Dividing images and labels: 180 / 1999
# Dividing images and labels: 181 / 1999
# Dividing images and labels: 182 / 1999
# Dividing images and labels: 183 / 1999
# Dividing images and labels: 184 / 1999
# Dividing images and labels: 185 / 1999
# Dividing images and labels: 186 / 1999
# Dividing images and labels: 187 / 1999
# Dividing images and labels: 188 / 1999
# Dividing images and labels: 189 / 1999
# Dividing images and labels: 190 / 1999
# Dividing images and labels: 191 / 1999
# Dividing images and labels: 192 / 1999
# Dividing images and labels: 193 / 1999
# Dividing images and labels: 194 / 1999
# Dividing images and labels: 195 / 1999
# Dividing images and labels: 196 / 1999
# Dividing images and labels: 197 / 1999
# Dividing images and labels: 198 / 1999
# Dividing images and labels: 199 / 1999
# Dividing images and labels: 200 / 1999
# Dividing images and labels: 201 / 1999
# Dividing images and labels: 202 / 1999
# Dividing images and labels: 203 / 1999
# Dividing images and labels: 204 / 1999
# Dividing images and labels: 205 / 1999
# Dividing images and labels: 206 / 1999
# Dividing images and labels: 207 / 1999
# Dividing images and labels: 208 / 1999
# Dividing images and labels: 209 / 1999
# Dividing images and labels: 210 / 1999
# Dividing images and labels: 211 / 1999
# Dividing images and labels: 212 / 1999
# Dividing images and labels: 213 / 1999
# Dividing images and labels: 214 / 1999
# Dividing images and labels: 215 / 1999
# Dividing images and labels: 216 / 1999
# Dividing images and labels: 217 / 1999
# Dividing images and labels: 218 / 1999
# Dividing images and labels: 219 / 1999
# Dividing images and labels: 220 / 1999
# Dividing images and labels: 221 / 1999
# Dividing images and labels: 222 / 1999
# Dividing images and labels: 223 / 1999
# Dividing images and labels: 224 / 1999
# Dividing images and labels: 225 / 1999
# Dividing images and labels: 226 / 1999
# Dividing images and labels: 227 / 1999
# Dividing images and labels: 228 / 1999
# Dividing images and labels: 229 / 1999
# Dividing images and labels: 230 / 1999
# Dividing images and labels: 231 / 1999
# Dividing images and labels: 232 / 1999
# Dividing images and labels: 233 / 1999
# Dividing images and labels: 234 / 1999
# Dividing images and labels: 235 / 1999
# Dividing images and labels: 236 / 1999
# Dividing images and labels: 237 / 1999
# Dividing images and labels: 238 / 1999
# Dividing images and labels: 239 / 1999
# Dividing images and labels: 240 / 1999
# Dividing images and labels: 241 / 1999
# Dividing images and labels: 242 / 1999
# Dividing images and labels: 243 / 1999
# Dividing images and labels: 244 / 1999
# Dividing images and labels: 245 / 1999
# Dividing images and labels: 246 / 1999
# Dividing images and labels: 247 / 1999
# Dividing images and labels: 248 / 1999
# Dividing images and labels: 249 / 1999
# Dividing images and labels: 250 / 1999
# Dividing images and labels: 251 / 1999
# Dividing images and labels: 252 / 1999
# Dividing images and labels: 253 / 1999
# Dividing images and labels: 254 / 1999
# Dividing images and labels: 255 / 1999
# Dividing images and labels: 256 / 1999
# Dividing images and labels: 257 / 1999
# Dividing images and labels: 258 / 1999
# Dividing images and labels: 259 / 1999
# Dividing images and labels: 260 / 1999
# Dividing images and labels: 261 / 1999
# Dividing images and labels: 262 / 1999
# Dividing images and labels: 263 / 1999
# Dividing images and labels: 264 / 1999
# Dividing images and labels: 265 / 1999
# Dividing images and labels: 266 / 1999
# Dividing images and labels: 267 / 1999
# Dividing images and labels: 268 / 1999
# Dividing images and labels: 269 / 1999
# Dividing images and labels: 270 / 1999
# Dividing images and labels: 271 / 1999
# Dividing images and labels: 272 / 1999
# Dividing images and labels: 273 / 1999
# Dividing images and labels: 274 / 1999
# Dividing images and labels: 275 / 1999
# Dividing images and labels: 276 / 1999
# Dividing images and labels: 277 / 1999
# Dividing images and labels: 278 / 1999
# Dividing images and labels: 279 / 1999
# Dividing images and labels: 280 / 1999
# Dividing images and labels: 281 / 1999
# Dividing images and labels: 282 / 1999
# Dividing images and labels: 283 / 1999
# Dividing images and labels: 284 / 1999
# Dividing images and labels: 285 / 1999
# Dividing images and labels: 286 / 1999
# Dividing images and labels: 287 / 1999
# Dividing images and labels: 288 / 1999
# Dividing images and labels: 289 / 1999
# Dividing images and labels: 290 / 1999
# Dividing images and labels: 291 / 1999
# Dividing images and labels: 292 / 1999
# Dividing images and labels: 293 / 1999
# Dividing images and labels: 294 / 1999
# Dividing images and labels: 295 / 1999
# Dividing images and labels: 296 / 1999
# Dividing images and labels: 297 / 1999
# Dividing images and labels: 298 / 1999
# Dividing images and labels: 299 / 1999
# Dividing images and labels: 300 / 1999
# Dividing images and labels: 301 / 1999
# Dividing images and labels: 302 / 1999
# Dividing images and labels: 303 / 1999
# Dividing images and labels: 304 / 1999
# Dividing images and labels: 305 / 1999
# Dividing images and labels: 306 / 1999
# Dividing images and labels: 307 / 1999
# Dividing images and labels: 308 / 1999
# Dividing images and labels: 309 / 1999
# Dividing images and labels: 310 / 1999
# Dividing images and labels: 311 / 1999
# Dividing images and labels: 312 / 1999
# Dividing images and labels: 313 / 1999
# Dividing images and labels: 314 / 1999
# Dividing images and labels: 315 / 1999
# Dividing images and labels: 316 / 1999
# Dividing images and labels: 317 / 1999
# Dividing images and labels: 318 / 1999
# Dividing images and labels: 319 / 1999
# Dividing images and labels: 320 / 1999
# Dividing images and labels: 321 / 1999
# Dividing images and labels: 322 / 1999
# Dividing images and labels: 323 / 1999
# Dividing images and labels: 324 / 1999
# Dividing images and labels: 325 / 1999
# Dividing images and labels: 326 / 1999
# Dividing images and labels: 327 / 1999
# Dividing images and labels: 328 / 1999
# Dividing images and labels: 329 / 1999
# Dividing images and labels: 330 / 1999
# Dividing images and labels: 331 / 1999
# Dividing images and labels: 332 / 1999
# Dividing images and labels: 333 / 1999
# Dividing images and labels: 334 / 1999
# Dividing images and labels: 335 / 1999
# Dividing images and labels: 336 / 1999
# Dividing images and labels: 337 / 1999
# Dividing images and labels: 338 / 1999
# Dividing images and labels: 339 / 1999
# Dividing images and labels: 340 / 1999
# Dividing images and labels: 341 / 1999
# Dividing images and labels: 342 / 1999
# Dividing images and labels: 343 / 1999
# Dividing images and labels: 344 / 1999
# Dividing images and labels: 345 / 1999
# Dividing images and labels: 346 / 1999
# Dividing images and labels: 347 / 1999
# Dividing images and labels: 348 / 1999
# Dividing images and labels: 349 / 1999
# Dividing images and labels: 350 / 1999
# Dividing images and labels: 351 / 1999
# Dividing images and labels: 352 / 1999
# Dividing images and labels: 353 / 1999
# Dividing images and labels: 354 / 1999
# Dividing images and labels: 355 / 1999
# Dividing images and labels: 356 / 1999
# Dividing images and labels: 357 / 1999
# Dividing images and labels: 358 / 1999
# Dividing images and labels: 359 / 1999
# Dividing images and labels: 360 / 1999
# Dividing images and labels: 361 / 1999
# Dividing images and labels: 362 / 1999
# Dividing images and labels: 363 / 1999
# Dividing images and labels: 364 / 1999
# Dividing images and labels: 365 / 1999
# Dividing images and labels: 366 / 1999
# Dividing images and labels: 367 / 1999
# Dividing images and labels: 368 / 1999
# Dividing images and labels: 369 / 1999
# Dividing images and labels: 370 / 1999
# Dividing images and labels: 371 / 1999
# Dividing images and labels: 372 / 1999
# Dividing images and labels: 373 / 1999
# Dividing images and labels: 374 / 1999
# Dividing images and labels: 375 / 1999
# Dividing images and labels: 376 / 1999
# Dividing images and labels: 377 / 1999
# Dividing images and labels: 378 / 1999
# Dividing images and labels: 379 / 1999
# Dividing images and labels: 380 / 1999
# Dividing images and labels: 381 / 1999
# Dividing images and labels: 382 / 1999
# Dividing images and labels: 383 / 1999
# Dividing images and labels: 384 / 1999
# Dividing images and labels: 385 / 1999
# Dividing images and labels: 386 / 1999
# Dividing images and labels: 387 / 1999
# Dividing images and labels: 388 / 1999
# Dividing images and labels: 389 / 1999
# Dividing images and labels: 390 / 1999
# Dividing images and labels: 391 / 1999
# Dividing images and labels: 392 / 1999
# Dividing images and labels: 393 / 1999
# Dividing images and labels: 394 / 1999
# Dividing images and labels: 395 / 1999
# Dividing images and labels: 396 / 1999
# Dividing images and labels: 397 / 1999
# Dividing images and labels: 398 / 1999
# Dividing images and labels: 399 / 1999
# Dividing images and labels: 400 / 1999
# Dividing images and labels: 401 / 1999
# Dividing images and labels: 402 / 1999
# Dividing images and labels: 403 / 1999
# Dividing images and labels: 404 / 1999
# Dividing images and labels: 405 / 1999
# Dividing images and labels: 406 / 1999
# Dividing images and labels: 407 / 1999
# Dividing images and labels: 408 / 1999
# Dividing images and labels: 409 / 1999
# Dividing images and labels: 410 / 1999
# Dividing images and labels: 411 / 1999
# Dividing images and labels: 412 / 1999
# Dividing images and labels: 413 / 1999
# Dividing images and labels: 414 / 1999
# Dividing images and labels: 415 / 1999
# Dividing images and labels: 416 / 1999
# Dividing images and labels: 417 / 1999
# Dividing images and labels: 418 / 1999
# Dividing images and labels: 419 / 1999
# Dividing images and labels: 420 / 1999
# Dividing images and labels: 421 / 1999
# Dividing images and labels: 422 / 1999
# Dividing images and labels: 423 / 1999
# Dividing images and labels: 424 / 1999
# Dividing images and labels: 425 / 1999
# Dividing images and labels: 426 / 1999
# Dividing images and labels: 427 / 1999
# Dividing images and labels: 428 / 1999
# Dividing images and labels: 429 / 1999
# Dividing images and labels: 430 / 1999
# Dividing images and labels: 431 / 1999
# Dividing images and labels: 432 / 1999
# Dividing images and labels: 433 / 1999
# Dividing images and labels: 434 / 1999
# Dividing images and labels: 435 / 1999
# Dividing images and labels: 436 / 1999
# Dividing images and labels: 437 / 1999
# Dividing images and labels: 438 / 1999
# Dividing images and labels: 439 / 1999
# Dividing images and labels: 440 / 1999
# Dividing images and labels: 441 / 1999
# Dividing images and labels: 442 / 1999
# Dividing images and labels: 443 / 1999
# Dividing images and labels: 444 / 1999
# Dividing images and labels: 445 / 1999
# Dividing images and labels: 446 / 1999
# Dividing images and labels: 447 / 1999
# Dividing images and labels: 448 / 1999
# Dividing images and labels: 449 / 1999
# Dividing images and labels: 450 / 1999
# Dividing images and labels: 451 / 1999
# Dividing images and labels: 452 / 1999
# Dividing images and labels: 453 / 1999
# Dividing images and labels: 454 / 1999
# Dividing images and labels: 455 / 1999
# Dividing images and labels: 456 / 1999
# Dividing images and labels: 457 / 1999
# Dividing images and labels: 458 / 1999
# Dividing images and labels: 459 / 1999
# Dividing images and labels: 460 / 1999
# Dividing images and labels: 461 / 1999
# Dividing images and labels: 462 / 1999
# Dividing images and labels: 463 / 1999
# Dividing images and labels: 464 / 1999
# Dividing images and labels: 465 / 1999
# Dividing images and labels: 466 / 1999
# Dividing images and labels: 467 / 1999
# Dividing images and labels: 468 / 1999
# Dividing images and labels: 469 / 1999
# Dividing images and labels: 470 / 1999
# Dividing images and labels: 471 / 1999
# Dividing images and labels: 472 / 1999
# Dividing images and labels: 473 / 1999
# Dividing images and labels: 474 / 1999
# Dividing images and labels: 475 / 1999
# Dividing images and labels: 476 / 1999
# Dividing images and labels: 477 / 1999
# Dividing images and labels: 478 / 1999
# Dividing images and labels: 479 / 1999
# Dividing images and labels: 480 / 1999
# Dividing images and labels: 481 / 1999
# Dividing images and labels: 482 / 1999
# Dividing images and labels: 483 / 1999
# Dividing images and labels: 484 / 1999
# Dividing images and labels: 485 / 1999
# Dividing images and labels: 486 / 1999
# Dividing images and labels: 487 / 1999
# Dividing images and labels: 488 / 1999
# Dividing images and labels: 489 / 1999
# Dividing images and labels: 490 / 1999
# Dividing images and labels: 491 / 1999
# Dividing images and labels: 492 / 1999
# Dividing images and labels: 493 / 1999
# Dividing images and labels: 494 / 1999
# Dividing images and labels: 495 / 1999
# Dividing images and labels: 496 / 1999
# Dividing images and labels: 497 / 1999
# Dividing images and labels: 498 / 1999
# Dividing images and labels: 499 / 1999
# Dividing images and labels: 500 / 1999
# Dividing images and labels: 501 / 1999
# Dividing images and labels: 502 / 1999
# Dividing images and labels: 503 / 1999
# Dividing images and labels: 504 / 1999
# Dividing images and labels: 505 / 1999
# Dividing images and labels: 506 / 1999
# Dividing images and labels: 507 / 1999
# Dividing images and labels: 508 / 1999
# Dividing images and labels: 509 / 1999
# Dividing images and labels: 510 / 1999
# Dividing images and labels: 511 / 1999
# Dividing images and labels: 512 / 1999
# Dividing images and labels: 513 / 1999
# Dividing images and labels: 514 / 1999
# Dividing images and labels: 515 / 1999
# Dividing images and labels: 516 / 1999
# Dividing images and labels: 517 / 1999
# Dividing images and labels: 518 / 1999
# Dividing images and labels: 519 / 1999
# Dividing images and labels: 520 / 1999
# Dividing images and labels: 521 / 1999
# Dividing images and labels: 522 / 1999
# Dividing images and labels: 523 / 1999
# Dividing images and labels: 524 / 1999
# Dividing images and labels: 525 / 1999
# Dividing images and labels: 526 / 1999
# Dividing images and labels: 527 / 1999
# Dividing images and labels: 528 / 1999
# Dividing images and labels: 529 / 1999
# Dividing images and labels: 530 / 1999
# Dividing images and labels: 531 / 1999
# Dividing images and labels: 532 / 1999
# Dividing images and labels: 533 / 1999
# Dividing images and labels: 534 / 1999
# Dividing images and labels: 535 / 1999
# Dividing images and labels: 536 / 1999
# Dividing images and labels: 537 / 1999
# Dividing images and labels: 538 / 1999
# Dividing images and labels: 539 / 1999
# Dividing images and labels: 540 / 1999
# Dividing images and labels: 541 / 1999
# Dividing images and labels: 542 / 1999
# Dividing images and labels: 543 / 1999
# Dividing images and labels: 544 / 1999
# Dividing images and labels: 545 / 1999
# Dividing images and labels: 546 / 1999
# Dividing images and labels: 547 / 1999
# Dividing images and labels: 548 / 1999
# Dividing images and labels: 549 / 1999
# Dividing images and labels: 550 / 1999
# Dividing images and labels: 551 / 1999
# Dividing images and labels: 552 / 1999
# Dividing images and labels: 553 / 1999
# Dividing images and labels: 554 / 1999
# Dividing images and labels: 555 / 1999
# Dividing images and labels: 556 / 1999
# Dividing images and labels: 557 / 1999
# Dividing images and labels: 558 / 1999
# Dividing images and labels: 559 / 1999
# Dividing images and labels: 560 / 1999
# Dividing images and labels: 561 / 1999
# Dividing images and labels: 562 / 1999
# Dividing images and labels: 563 / 1999
# Dividing images and labels: 564 / 1999
# Dividing images and labels: 565 / 1999
# Dividing images and labels: 566 / 1999
# Dividing images and labels: 567 / 1999
# Dividing images and labels: 568 / 1999
# Dividing images and labels: 569 / 1999
# Dividing images and labels: 570 / 1999
# Dividing images and labels: 571 / 1999
# Dividing images and labels: 572 / 1999
# Dividing images and labels: 573 / 1999
# Dividing images and labels: 574 / 1999
# Dividing images and labels: 575 / 1999
# Dividing images and labels: 576 / 1999
# Dividing images and labels: 577 / 1999
# Dividing images and labels: 578 / 1999
# Dividing images and labels: 579 / 1999
# Dividing images and labels: 580 / 1999
# Dividing images and labels: 581 / 1999
# Dividing images and labels: 582 / 1999
# Dividing images and labels: 583 / 1999
# Dividing images and labels: 584 / 1999
# Dividing images and labels: 585 / 1999
# Dividing images and labels: 586 / 1999
# Dividing images and labels: 587 / 1999
# Dividing images and labels: 588 / 1999
# Dividing images and labels: 589 / 1999
# Dividing images and labels: 590 / 1999
# Dividing images and labels: 591 / 1999
# Dividing images and labels: 592 / 1999
# Dividing images and labels: 593 / 1999
# Dividing images and labels: 594 / 1999
# Dividing images and labels: 595 / 1999
# Dividing images and labels: 596 / 1999
# Dividing images and labels: 597 / 1999
# Dividing images and labels: 598 / 1999
# Dividing images and labels: 599 / 1999
# Dividing images and labels: 600 / 1999
# Dividing images and labels: 601 / 1999
# Dividing images and labels: 602 / 1999
# Dividing images and labels: 603 / 1999
# Dividing images and labels: 604 / 1999
# Dividing images and labels: 605 / 1999
# Dividing images and labels: 606 / 1999
# Dividing images and labels: 607 / 1999
# Dividing images and labels: 608 / 1999
# Dividing images and labels: 609 / 1999
# Dividing images and labels: 610 / 1999
# Dividing images and labels: 611 / 1999
# Dividing images and labels: 612 / 1999
# Dividing images and labels: 613 / 1999
# Dividing images and labels: 614 / 1999
# Dividing images and labels: 615 / 1999
# Dividing images and labels: 616 / 1999
# Dividing images and labels: 617 / 1999
# Dividing images and labels: 618 / 1999
# Dividing images and labels: 619 / 1999
# Dividing images and labels: 620 / 1999
# Dividing images and labels: 621 / 1999
# Dividing images and labels: 622 / 1999
# Dividing images and labels: 623 / 1999
# Dividing images and labels: 624 / 1999
# Dividing images and labels: 625 / 1999
# Dividing images and labels: 626 / 1999
# Dividing images and labels: 627 / 1999
# Dividing images and labels: 628 / 1999
# Dividing images and labels: 629 / 1999
# Dividing images and labels: 630 / 1999
# Dividing images and labels: 631 / 1999
# Dividing images and labels: 632 / 1999
# Dividing images and labels: 633 / 1999
# Dividing images and labels: 634 / 1999
# Dividing images and labels: 635 / 1999
# Dividing images and labels: 636 / 1999
# Dividing images and labels: 637 / 1999
# Dividing images and labels: 638 / 1999
# Dividing images and labels: 639 / 1999
# Dividing images and labels: 640 / 1999
# Dividing images and labels: 641 / 1999
# Dividing images and labels: 642 / 1999
# Dividing images and labels: 643 / 1999
# Dividing images and labels: 644 / 1999
# Dividing images and labels: 645 / 1999
# Dividing images and labels: 646 / 1999
# Dividing images and labels: 647 / 1999
# Dividing images and labels: 648 / 1999
# Dividing images and labels: 649 / 1999
# Dividing images and labels: 650 / 1999
# Dividing images and labels: 651 / 1999
# Dividing images and labels: 652 / 1999
# Dividing images and labels: 653 / 1999
# Dividing images and labels: 654 / 1999
# Dividing images and labels: 655 / 1999
# Dividing images and labels: 656 / 1999
# Dividing images and labels: 657 / 1999
# Dividing images and labels: 658 / 1999
# Dividing images and labels: 659 / 1999
# Dividing images and labels: 660 / 1999
# Dividing images and labels: 661 / 1999
# Dividing images and labels: 662 / 1999
# Dividing images and labels: 663 / 1999
# Dividing images and labels: 664 / 1999
# Dividing images and labels: 665 / 1999
# Dividing images and labels: 666 / 1999
# Dividing images and labels: 667 / 1999
# Dividing images and labels: 668 / 1999
# Dividing images and labels: 669 / 1999
# Dividing images and labels: 670 / 1999
# Dividing images and labels: 671 / 1999
# Dividing images and labels: 672 / 1999
# Dividing images and labels: 673 / 1999
# Dividing images and labels: 674 / 1999
# Dividing images and labels: 675 / 1999
# Dividing images and labels: 676 / 1999
# Dividing images and labels: 677 / 1999
# Dividing images and labels: 678 / 1999
# Dividing images and labels: 679 / 1999
# Dividing images and labels: 680 / 1999
# Dividing images and labels: 681 / 1999
# Dividing images and labels: 682 / 1999
# Dividing images and labels: 683 / 1999
# Dividing images and labels: 684 / 1999
# Dividing images and labels: 685 / 1999
# Dividing images and labels: 686 / 1999
# Dividing images and labels: 687 / 1999
# Dividing images and labels: 688 / 1999
# Dividing images and labels: 689 / 1999
# Dividing images and labels: 690 / 1999
# Dividing images and labels: 691 / 1999
# Dividing images and labels: 692 / 1999
# Dividing images and labels: 693 / 1999
# Dividing images and labels: 694 / 1999
# Dividing images and labels: 695 / 1999
# Dividing images and labels: 696 / 1999
# Dividing images and labels: 697 / 1999
# Dividing images and labels: 698 / 1999
# Dividing images and labels: 699 / 1999
# Dividing images and labels: 700 / 1999
# Dividing images and labels: 701 / 1999
# Dividing images and labels: 702 / 1999
# Dividing images and labels: 703 / 1999
# Dividing images and labels: 704 / 1999
# Dividing images and labels: 705 / 1999
# Dividing images and labels: 706 / 1999
# Dividing images and labels: 707 / 1999
# Dividing images and labels: 708 / 1999
# Dividing images and labels: 709 / 1999
# Dividing images and labels: 710 / 1999
# Dividing images and labels: 711 / 1999
# Dividing images and labels: 712 / 1999
# Dividing images and labels: 713 / 1999
# Dividing images and labels: 714 / 1999
# Dividing images and labels: 715 / 1999
# Dividing images and labels: 716 / 1999
# Dividing images and labels: 717 / 1999
# Dividing images and labels: 718 / 1999
# Dividing images and labels: 719 / 1999
# Dividing images and labels: 720 / 1999
# Dividing images and labels: 721 / 1999
# Dividing images and labels: 722 / 1999
# Dividing images and labels: 723 / 1999
# Dividing images and labels: 724 / 1999
# Dividing images and labels: 725 / 1999
# Dividing images and labels: 726 / 1999
# Dividing images and labels: 727 / 1999
# Dividing images and labels: 728 / 1999
# Dividing images and labels: 729 / 1999
# Dividing images and labels: 730 / 1999
# Dividing images and labels: 731 / 1999
# Dividing images and labels: 732 / 1999
# Dividing images and labels: 733 / 1999
# Dividing images and labels: 734 / 1999
# Dividing images and labels: 735 / 1999
# Dividing images and labels: 736 / 1999
# Dividing images and labels: 737 / 1999
# Dividing images and labels: 738 / 1999
# Dividing images and labels: 739 / 1999
# Dividing images and labels: 740 / 1999
# Dividing images and labels: 741 / 1999
# Dividing images and labels: 742 / 1999
# Dividing images and labels: 743 / 1999
# Dividing images and labels: 744 / 1999
# Dividing images and labels: 745 / 1999
# Dividing images and labels: 746 / 1999
# Dividing images and labels: 747 / 1999
# Dividing images and labels: 748 / 1999
# Dividing images and labels: 749 / 1999
# Dividing images and labels: 750 / 1999
# Dividing images and labels: 751 / 1999
# Dividing images and labels: 752 / 1999
# Dividing images and labels: 753 / 1999
# Dividing images and labels: 754 / 1999
# Dividing images and labels: 755 / 1999
# Dividing images and labels: 756 / 1999
# Dividing images and labels: 757 / 1999
# Dividing images and labels: 758 / 1999
# Dividing images and labels: 759 / 1999
# Dividing images and labels: 760 / 1999
# Dividing images and labels: 761 / 1999
# Dividing images and labels: 762 / 1999
# Dividing images and labels: 763 / 1999
# Dividing images and labels: 764 / 1999
# Dividing images and labels: 765 / 1999
# Dividing images and labels: 766 / 1999
# Dividing images and labels: 767 / 1999
# Dividing images and labels: 768 / 1999
# Dividing images and labels: 769 / 1999
# Dividing images and labels: 770 / 1999
# Dividing images and labels: 771 / 1999
# Dividing images and labels: 772 / 1999
# Dividing images and labels: 773 / 1999
# Dividing images and labels: 774 / 1999
# Dividing images and labels: 775 / 1999
# Dividing images and labels: 776 / 1999
# Dividing images and labels: 777 / 1999
# Dividing images and labels: 778 / 1999
# Dividing images and labels: 779 / 1999
# Dividing images and labels: 780 / 1999
# Dividing images and labels: 781 / 1999
# Dividing images and labels: 782 / 1999
# Dividing images and labels: 783 / 1999
# Dividing images and labels: 784 / 1999
# Dividing images and labels: 785 / 1999
# Dividing images and labels: 786 / 1999
# Dividing images and labels: 787 / 1999
# Dividing images and labels: 788 / 1999
# Dividing images and labels: 789 / 1999
# Dividing images and labels: 790 / 1999
# Dividing images and labels: 791 / 1999
# Dividing images and labels: 792 / 1999
# Dividing images and labels: 793 / 1999
# Dividing images and labels: 794 / 1999
# Dividing images and labels: 795 / 1999
# Dividing images and labels: 796 / 1999
# Dividing images and labels: 797 / 1999
# Dividing images and labels: 798 / 1999
# Dividing images and labels: 799 / 1999
# Dividing images and labels: 800 / 1999
# Dividing images and labels: 801 / 1999
# Dividing images and labels: 802 / 1999
# Dividing images and labels: 803 / 1999
# Dividing images and labels: 804 / 1999
# Dividing images and labels: 805 / 1999
# Dividing images and labels: 806 / 1999
# Dividing images and labels: 807 / 1999
# Dividing images and labels: 808 / 1999
# Dividing images and labels: 809 / 1999
# Dividing images and labels: 810 / 1999
# Dividing images and labels: 811 / 1999
# Dividing images and labels: 812 / 1999
# Dividing images and labels: 813 / 1999
# Dividing images and labels: 814 / 1999
# Dividing images and labels: 815 / 1999
# Dividing images and labels: 816 / 1999
# Dividing images and labels: 817 / 1999
# Dividing images and labels: 818 / 1999
# Dividing images and labels: 819 / 1999
# Dividing images and labels: 820 / 1999
# Dividing images and labels: 821 / 1999
# Dividing images and labels: 822 / 1999
# Dividing images and labels: 823 / 1999
# Dividing images and labels: 824 / 1999
# Dividing images and labels: 825 / 1999
# Dividing images and labels: 826 / 1999
# Dividing images and labels: 827 / 1999
# Dividing images and labels: 828 / 1999
# Dividing images and labels: 829 / 1999
# Dividing images and labels: 830 / 1999
# Dividing images and labels: 831 / 1999
# Dividing images and labels: 832 / 1999
# Dividing images and labels: 833 / 1999
# Dividing images and labels: 834 / 1999
# Dividing images and labels: 835 / 1999
# Dividing images and labels: 836 / 1999
# Dividing images and labels: 837 / 1999
# Dividing images and labels: 838 / 1999
# Dividing images and labels: 839 / 1999
# Dividing images and labels: 840 / 1999
# Dividing images and labels: 841 / 1999
# Dividing images and labels: 842 / 1999
# Dividing images and labels: 843 / 1999
# Dividing images and labels: 844 / 1999
# Dividing images and labels: 845 / 1999
# Dividing images and labels: 846 / 1999
# Dividing images and labels: 847 / 1999
# Dividing images and labels: 848 / 1999
# Dividing images and labels: 849 / 1999
# Dividing images and labels: 850 / 1999
# Dividing images and labels: 851 / 1999
# Dividing images and labels: 852 / 1999
# Dividing images and labels: 853 / 1999
# Dividing images and labels: 854 / 1999
# Dividing images and labels: 855 / 1999
# Dividing images and labels: 856 / 1999
# Dividing images and labels: 857 / 1999
# Dividing images and labels: 858 / 1999
# Dividing images and labels: 859 / 1999
# Dividing images and labels: 860 / 1999
# Dividing images and labels: 861 / 1999
# Dividing images and labels: 862 / 1999
# Dividing images and labels: 863 / 1999
# Dividing images and labels: 864 / 1999
# Dividing images and labels: 865 / 1999
# Dividing images and labels: 866 / 1999
# Dividing images and labels: 867 / 1999
# Dividing images and labels: 868 / 1999
# Dividing images and labels: 869 / 1999
# Dividing images and labels: 870 / 1999
# Dividing images and labels: 871 / 1999
# Dividing images and labels: 872 / 1999
# Dividing images and labels: 873 / 1999
# Dividing images and labels: 874 / 1999
# Dividing images and labels: 875 / 1999
# Dividing images and labels: 876 / 1999
# Dividing images and labels: 877 / 1999
# Dividing images and labels: 878 / 1999
# Dividing images and labels: 879 / 1999
# Dividing images and labels: 880 / 1999
# Dividing images and labels: 881 / 1999
# Dividing images and labels: 882 / 1999
# Dividing images and labels: 883 / 1999
# Dividing images and labels: 884 / 1999
# Dividing images and labels: 885 / 1999
# Dividing images and labels: 886 / 1999
# Dividing images and labels: 887 / 1999
# Dividing images and labels: 888 / 1999
# Dividing images and labels: 889 / 1999
# Dividing images and labels: 890 / 1999
# Dividing images and labels: 891 / 1999
# Dividing images and labels: 892 / 1999
# Dividing images and labels: 893 / 1999
# Dividing images and labels: 894 / 1999
# Dividing images and labels: 895 / 1999
# Dividing images and labels: 896 / 1999
# Dividing images and labels: 897 / 1999
# Dividing images and labels: 898 / 1999
# Dividing images and labels: 899 / 1999
# Dividing images and labels: 900 / 1999
# Dividing images and labels: 901 / 1999
# Dividing images and labels: 902 / 1999
# Dividing images and labels: 903 / 1999
# Dividing images and labels: 904 / 1999
# Dividing images and labels: 905 / 1999
# Dividing images and labels: 906 / 1999
# Dividing images and labels: 907 / 1999
# Dividing images and labels: 908 / 1999
# Dividing images and labels: 909 / 1999
# Dividing images and labels: 910 / 1999
# Dividing images and labels: 911 / 1999
# Dividing images and labels: 912 / 1999
# Dividing images and labels: 913 / 1999
# Dividing images and labels: 914 / 1999
# Dividing images and labels: 915 / 1999
# Dividing images and labels: 916 / 1999
# Dividing images and labels: 917 / 1999
# Dividing images and labels: 918 / 1999
# Dividing images and labels: 919 / 1999
# Dividing images and labels: 920 / 1999
# Dividing images and labels: 921 / 1999
# Dividing images and labels: 922 / 1999
# Dividing images and labels: 923 / 1999
# Dividing images and labels: 924 / 1999
# Dividing images and labels: 925 / 1999
# Dividing images and labels: 926 / 1999
# Dividing images and labels: 927 / 1999
# Dividing images and labels: 928 / 1999
# Dividing images and labels: 929 / 1999
# Dividing images and labels: 930 / 1999
# Dividing images and labels: 931 / 1999
# Dividing images and labels: 932 / 1999
# Dividing images and labels: 933 / 1999
# Dividing images and labels: 934 / 1999
# Dividing images and labels: 935 / 1999
# Dividing images and labels: 936 / 1999
# Dividing images and labels: 937 / 1999
# Dividing images and labels: 938 / 1999
# Dividing images and labels: 939 / 1999
# Dividing images and labels: 940 / 1999
# Dividing images and labels: 941 / 1999
# Dividing images and labels: 942 / 1999
# Dividing images and labels: 943 / 1999
# Dividing images and labels: 944 / 1999
# Dividing images and labels: 945 / 1999
# Dividing images and labels: 946 / 1999
# Dividing images and labels: 947 / 1999
# Dividing images and labels: 948 / 1999
# Dividing images and labels: 949 / 1999
# Dividing images and labels: 950 / 1999
# Dividing images and labels: 951 / 1999
# Dividing images and labels: 952 / 1999
# Dividing images and labels: 953 / 1999
# Dividing images and labels: 954 / 1999
# Dividing images and labels: 955 / 1999
# Dividing images and labels: 956 / 1999
# Dividing images and labels: 957 / 1999
# Dividing images and labels: 958 / 1999
# Dividing images and labels: 959 / 1999
# Dividing images and labels: 960 / 1999
# Dividing images and labels: 961 / 1999
# Dividing images and labels: 962 / 1999
# Dividing images and labels: 963 / 1999
# Dividing images and labels: 964 / 1999
# Dividing images and labels: 965 / 1999
# Dividing images and labels: 966 / 1999
# Dividing images and labels: 967 / 1999
# Dividing images and labels: 968 / 1999
# Dividing images and labels: 969 / 1999
# Dividing images and labels: 970 / 1999
# Dividing images and labels: 971 / 1999
# Dividing images and labels: 972 / 1999
# Dividing images and labels: 973 / 1999
# Dividing images and labels: 974 / 1999
# Dividing images and labels: 975 / 1999
# Dividing images and labels: 976 / 1999
# Dividing images and labels: 977 / 1999
# Dividing images and labels: 978 / 1999
# Dividing images and labels: 979 / 1999
# Dividing images and labels: 980 / 1999
# Dividing images and labels: 981 / 1999
# Dividing images and labels: 982 / 1999
# Dividing images and labels: 983 / 1999
# Dividing images and labels: 984 / 1999
# Dividing images and labels: 985 / 1999
# Dividing images and labels: 986 / 1999
# Dividing images and labels: 987 / 1999
# Dividing images and labels: 988 / 1999
# Dividing images and labels: 989 / 1999
# Dividing images and labels: 990 / 1999
# Dividing images and labels: 991 / 1999
# Dividing images and labels: 992 / 1999
# Dividing images and labels: 993 / 1999
# Dividing images and labels: 994 / 1999
# Dividing images and labels: 995 / 1999
# Dividing images and labels: 996 / 1999
# Dividing images and labels: 997 / 1999
# Dividing images and labels: 998 / 1999
# Dividing images and labels: 999 / 1999
# Dividing images and labels: 1000 / 1999
# Dividing images and labels: 1001 / 1999
# Dividing images and labels: 1002 / 1999
# Dividing images and labels: 1003 / 1999
# Dividing images and labels: 1004 / 1999
# Dividing images and labels: 1005 / 1999
# Dividing images and labels: 1006 / 1999
# Dividing images and labels: 1007 / 1999
# Dividing images and labels: 1008 / 1999
# Dividing images and labels: 1009 / 1999
# Dividing images and labels: 1010 / 1999
# Dividing images and labels: 1011 / 1999
# Dividing images and labels: 1012 / 1999
# Dividing images and labels: 1013 / 1999
# Dividing images and labels: 1014 / 1999
# Dividing images and labels: 1015 / 1999
# Dividing images and labels: 1016 / 1999
# Dividing images and labels: 1017 / 1999
# Dividing images and labels: 1018 / 1999
# Dividing images and labels: 1019 / 1999
# Dividing images and labels: 1020 / 1999
# Dividing images and labels: 1021 / 1999
# Dividing images and labels: 1022 / 1999
# Dividing images and labels: 1023 / 1999
# Dividing images and labels: 1024 / 1999
# Dividing images and labels: 1025 / 1999
# Dividing images and labels: 1026 / 1999
# Dividing images and labels: 1027 / 1999
# Dividing images and labels: 1028 / 1999
# Dividing images and labels: 1029 / 1999
# Dividing images and labels: 1030 / 1999
# Dividing images and labels: 1031 / 1999
# Dividing images and labels: 1032 / 1999
# Dividing images and labels: 1033 / 1999
# Dividing images and labels: 1034 / 1999
# Dividing images and labels: 1035 / 1999
# Dividing images and labels: 1036 / 1999
# Dividing images and labels: 1037 / 1999
# Dividing images and labels: 1038 / 1999
# Dividing images and labels: 1039 / 1999
# Dividing images and labels: 1040 / 1999
# Dividing images and labels: 1041 / 1999
# Dividing images and labels: 1042 / 1999
# Dividing images and labels: 1043 / 1999
# Dividing images and labels: 1044 / 1999
# Dividing images and labels: 1045 / 1999
# Dividing images and labels: 1046 / 1999
# Dividing images and labels: 1047 / 1999
# Dividing images and labels: 1048 / 1999
# Dividing images and labels: 1049 / 1999
# Dividing images and labels: 1050 / 1999
# Dividing images and labels: 1051 / 1999
# Dividing images and labels: 1052 / 1999
# Dividing images and labels: 1053 / 1999
# Dividing images and labels: 1054 / 1999
# Dividing images and labels: 1055 / 1999
# Dividing images and labels: 1056 / 1999
# Dividing images and labels: 1057 / 1999
# Dividing images and labels: 1058 / 1999
# Dividing images and labels: 1059 / 1999
# Dividing images and labels: 1060 / 1999
# Dividing images and labels: 1061 / 1999
# Dividing images and labels: 1062 / 1999
# Dividing images and labels: 1063 / 1999
# Dividing images and labels: 1064 / 1999
# Dividing images and labels: 1065 / 1999
# Dividing images and labels: 1066 / 1999
# Dividing images and labels: 1067 / 1999
# Dividing images and labels: 1068 / 1999
# Dividing images and labels: 1069 / 1999
# Dividing images and labels: 1070 / 1999
# Dividing images and labels: 1071 / 1999
# Dividing images and labels: 1072 / 1999
# Dividing images and labels: 1073 / 1999
# Dividing images and labels: 1074 / 1999
# Dividing images and labels: 1075 / 1999
# Dividing images and labels: 1076 / 1999
# Dividing images and labels: 1077 / 1999
# Dividing images and labels: 1078 / 1999
# Dividing images and labels: 1079 / 1999
# Dividing images and labels: 1080 / 1999
# Dividing images and labels: 1081 / 1999
# Dividing images and labels: 1082 / 1999
# Dividing images and labels: 1083 / 1999
# Dividing images and labels: 1084 / 1999
# Dividing images and labels: 1085 / 1999
# Dividing images and labels: 1086 / 1999
# Dividing images and labels: 1087 / 1999
# Dividing images and labels: 1088 / 1999
# Dividing images and labels: 1089 / 1999
# Dividing images and labels: 1090 / 1999
# Dividing images and labels: 1091 / 1999
# Dividing images and labels: 1092 / 1999
# Dividing images and labels: 1093 / 1999
# Dividing images and labels: 1094 / 1999
# Dividing images and labels: 1095 / 1999
# Dividing images and labels: 1096 / 1999
# Dividing images and labels: 1097 / 1999
# Dividing images and labels: 1098 / 1999
# Dividing images and labels: 1099 / 1999
# Dividing images and labels: 1100 / 1999
# Dividing images and labels: 1101 / 1999
# Dividing images and labels: 1102 / 1999
# Dividing images and labels: 1103 / 1999
# Dividing images and labels: 1104 / 1999
# Dividing images and labels: 1105 / 1999
# Dividing images and labels: 1106 / 1999
# Dividing images and labels: 1107 / 1999
# Dividing images and labels: 1108 / 1999
# Dividing images and labels: 1109 / 1999
# Dividing images and labels: 1110 / 1999
# Dividing images and labels: 1111 / 1999
# Dividing images and labels: 1112 / 1999
# Dividing images and labels: 1113 / 1999
# Dividing images and labels: 1114 / 1999
# Dividing images and labels: 1115 / 1999
# Dividing images and labels: 1116 / 1999
# Dividing images and labels: 1117 / 1999
# Dividing images and labels: 1118 / 1999
# Dividing images and labels: 1119 / 1999
# Dividing images and labels: 1120 / 1999
# Dividing images and labels: 1121 / 1999
# Dividing images and labels: 1122 / 1999
# Dividing images and labels: 1123 / 1999
# Dividing images and labels: 1124 / 1999
# Dividing images and labels: 1125 / 1999
# Dividing images and labels: 1126 / 1999
# Dividing images and labels: 1127 / 1999
# Dividing images and labels: 1128 / 1999
# Dividing images and labels: 1129 / 1999
# Dividing images and labels: 1130 / 1999
# Dividing images and labels: 1131 / 1999
# Dividing images and labels: 1132 / 1999
# Dividing images and labels: 1133 / 1999
# Dividing images and labels: 1134 / 1999
# Dividing images and labels: 1135 / 1999
# Dividing images and labels: 1136 / 1999
# Dividing images and labels: 1137 / 1999
# Dividing images and labels: 1138 / 1999
# Dividing images and labels: 1139 / 1999
# Dividing images and labels: 1140 / 1999
# Dividing images and labels: 1141 / 1999
# Dividing images and labels: 1142 / 1999
# Dividing images and labels: 1143 / 1999
# Dividing images and labels: 1144 / 1999
# Dividing images and labels: 1145 / 1999
# Dividing images and labels: 1146 / 1999
# Dividing images and labels: 1147 / 1999
# Dividing images and labels: 1148 / 1999
# Dividing images and labels: 1149 / 1999
# Dividing images and labels: 1150 / 1999
# Dividing images and labels: 1151 / 1999
# Dividing images and labels: 1152 / 1999
# Dividing images and labels: 1153 / 1999
# Dividing images and labels: 1154 / 1999
# Dividing images and labels: 1155 / 1999
# Dividing images and labels: 1156 / 1999
# Dividing images and labels: 1157 / 1999
# Dividing images and labels: 1158 / 1999
# Dividing images and labels: 1159 / 1999
# Dividing images and labels: 1160 / 1999
# Dividing images and labels: 1161 / 1999
# Dividing images and labels: 1162 / 1999
# Dividing images and labels: 1163 / 1999
# Dividing images and labels: 1164 / 1999
# Dividing images and labels: 1165 / 1999
# Dividing images and labels: 1166 / 1999
# Dividing images and labels: 1167 / 1999
# Dividing images and labels: 1168 / 1999
# Dividing images and labels: 1169 / 1999
# Dividing images and labels: 1170 / 1999
# Dividing images and labels: 1171 / 1999
# Dividing images and labels: 1172 / 1999
# Dividing images and labels: 1173 / 1999
# Dividing images and labels: 1174 / 1999
# Dividing images and labels: 1175 / 1999
# Dividing images and labels: 1176 / 1999
# Dividing images and labels: 1177 / 1999
# Dividing images and labels: 1178 / 1999
# Dividing images and labels: 1179 / 1999
# Dividing images and labels: 1180 / 1999
# Dividing images and labels: 1181 / 1999
# Dividing images and labels: 1182 / 1999
# Dividing images and labels: 1183 / 1999
# Dividing images and labels: 1184 / 1999
# Dividing images and labels: 1185 / 1999
# Dividing images and labels: 1186 / 1999
# Dividing images and labels: 1187 / 1999
# Dividing images and labels: 1188 / 1999
# Dividing images and labels: 1189 / 1999
# Dividing images and labels: 1190 / 1999
# Dividing images and labels: 1191 / 1999
# Dividing images and labels: 1192 / 1999
# Dividing images and labels: 1193 / 1999
# Dividing images and labels: 1194 / 1999
# Dividing images and labels: 1195 / 1999
# Dividing images and labels: 1196 / 1999
# Dividing images and labels: 1197 / 1999
# Dividing images and labels: 1198 / 1999
# Dividing images and labels: 1199 / 1999
# Dividing images and labels: 1200 / 1999
# Dividing images and labels: 1201 / 1999
# Dividing images and labels: 1202 / 1999
# Dividing images and labels: 1203 / 1999
# Dividing images and labels: 1204 / 1999
# Dividing images and labels: 1205 / 1999
# Dividing images and labels: 1206 / 1999
# Dividing images and labels: 1207 / 1999
# Dividing images and labels: 1208 / 1999
# Dividing images and labels: 1209 / 1999
# Dividing images and labels: 1210 / 1999
# Dividing images and labels: 1211 / 1999
# Dividing images and labels: 1212 / 1999
# Dividing images and labels: 1213 / 1999
# Dividing images and labels: 1214 / 1999
# Dividing images and labels: 1215 / 1999
# Dividing images and labels: 1216 / 1999
# Dividing images and labels: 1217 / 1999
# Dividing images and labels: 1218 / 1999
# Dividing images and labels: 1219 / 1999
# Dividing images and labels: 1220 / 1999
# Dividing images and labels: 1221 / 1999
# Dividing images and labels: 1222 / 1999
# Dividing images and labels: 1223 / 1999
# Dividing images and labels: 1224 / 1999
# Dividing images and labels: 1225 / 1999
# Dividing images and labels: 1226 / 1999
# Dividing images and labels: 1227 / 1999
# ...
# Dividing images and labels: 1600 / 1999
# Dividing images and labels: 1601 / 1999
# Dividing images and labels: 1602 / 1999
# Dividing images and labels: 1603 / 1999
# Dividing images and labels: 1604 / 1999
# Dividing images and labels: 1605 / 1999
# Dividing images and labels: 1606 / 1999
# Dividing images and labels: 1607 / 1999
# Dividing images and labels: 1608 / 1999
# Dividing images and labels: 1609 / 1999
# Dividing images and labels: 1610 / 1999
# Dividing images and labels: 1611 / 1999
# Dividing images and labels: 1612 / 1999
# Dividing images and labels: 1613 / 1999
# Dividing images and labels: 1614 / 1999
# Dividing images and labels: 1615 / 1999
# Dividing images and labels: 1616 / 1999
# Dividing images and labels: 1617 / 1999
# Dividing images and labels: 1618 / 1999
# Dividing images and labels: 1619 / 1999
# Dividing images and labels: 1620 / 1999
# Dividing images and labels: 1621 / 1999
# Dividing images and labels: 1622 / 1999
# Dividing images and labels: 1623 / 1999
# Dividing images and labels: 1624 / 1999
# Dividing images and labels: 1625 / 1999
# Dividing images and labels: 1626 / 1999
# Dividing images and labels: 1627 / 1999
# Dividing images and labels: 1628 / 1999
# Dividing images and labels: 1629 / 1999
# Dividing images and labels: 1630 / 1999
# Dividing images and labels: 1631 / 1999
# Dividing images and labels: 1632 / 1999
# Dividing images and labels: 1633 / 1999
# Dividing images and labels: 1634 / 1999
# Dividing images and labels: 1635 / 1999
# Dividing images and labels: 1636 / 1999
# Dividing images and labels: 1637 / 1999
# Dividing images and labels: 1638 / 1999
# Dividing images and labels: 1639 / 1999
# Dividing images and labels: 1640 / 1999
# Dividing images and labels: 1641 / 1999
# Dividing images and labels: 1642 / 1999
# Dividing images and labels: 1643 / 1999
# Dividing images and labels: 1644 / 1999
# Dividing images and labels: 1645 / 1999
# Dividing images and labels: 1646 / 1999
# Dividing images and labels: 1647 / 1999
# Dividing images and labels: 1648 / 1999
# Dividing images and labels: 1649 / 1999
# Dividing images and labels: 1650 / 1999
# Dividing images and labels: 1651 / 1999
# Dividing images and labels: 1652 / 1999
# Dividing images and labels: 1653 / 1999
# Dividing images and labels: 1654 / 1999
# Dividing images and labels: 1655 / 1999
# Dividing images and labels: 1656 / 1999
# Dividing images and labels: 1657 / 1999
# Dividing images and labels: 1658 / 1999
# Dividing images and labels: 1659 / 1999
# Dividing images and labels: 1660 / 1999
# Dividing images and labels: 1661 / 1999
# Dividing images and labels: 1662 / 1999
# Dividing images and labels: 1663 / 1999
# Dividing images and labels: 1664 / 1999
# Dividing images and labels: 1665 / 1999
# Dividing images and labels: 1666 / 1999
# Dividing images and labels: 1667 / 1999
# Dividing images and labels: 1668 / 1999
# Dividing images and labels: 1669 / 1999
# Dividing images and labels: 1670 / 1999
# Dividing images and labels: 1671 / 1999
# Dividing images and labels: 1672 / 1999
# Dividing images and labels: 1673 / 1999
# Dividing images and labels: 1674 / 1999
# Dividing images and labels: 1675 / 1999
# Dividing images and labels: 1676 / 1999
# Dividing images and labels: 1677 / 1999
# Dividing images and labels: 1678 / 1999
# Dividing images and labels: 1679 / 1999
# Dividing images and labels: 1680 / 1999
# Dividing images and labels: 1681 / 1999
# Dividing images and labels: 1682 / 1999
# Dividing images and labels: 1683 / 1999
# Dividing images and labels: 1684 / 1999
# Dividing images and labels: 1685 / 1999
# Dividing images and labels: 1686 / 1999
# Dividing images and labels: 1687 / 1999
# Dividing images and labels: 1688 / 1999
# Dividing images and labels: 1689 / 1999
# Dividing images and labels: 1690 / 1999
# Dividing images and labels: 1691 / 1999
# Dividing images and labels: 1692 / 1999
# Dividing images and labels: 1693 / 1999
# Dividing images and labels: 1694 / 1999
# Dividing images and labels: 1695 / 1999
# Dividing images and labels: 1696 / 1999
# Dividing images and labels: 1697 / 1999
# Dividing images and labels: 1698 / 1999
# Dividing images and labels: 1699 / 1999
# Dividing images and labels: 1700 / 1999
# Dividing images and labels: 1701 / 1999
# Dividing images and labels: 1702 / 1999
# Dividing images and labels: 1703 / 1999
# Dividing images and labels: 1704 / 1999
# Dividing images and labels: 1705 / 1999
# Dividing images and labels: 1706 / 1999
# Dividing images and labels: 1707 / 1999
# Dividing images and labels: 1708 / 1999
# Dividing images and labels: 1709 / 1999
# Dividing images and labels: 1710 / 1999
# Dividing images and labels: 1711 / 1999
# Dividing images and labels: 1712 / 1999
# Dividing images and labels: 1713 / 1999
# Dividing images and labels: 1714 / 1999
# Dividing images and labels: 1715 / 1999
# Dividing images and labels: 1716 / 1999
# Dividing images and labels: 1717 / 1999
# Dividing images and labels: 1718 / 1999
# Dividing images and labels: 1719 / 1999
# Dividing images and labels: 1720 / 1999
# Dividing images and labels: 1721 / 1999
# Dividing images and labels: 1722 / 1999
# Dividing images and labels: 1723 / 1999
# Dividing images and labels: 1724 / 1999
# Dividing images and labels: 1725 / 1999
# Dividing images and labels: 1726 / 1999
# Dividing images and labels: 1727 / 1999
# Dividing images and labels: 1728 / 1999
# Dividing images and labels: 1729 / 1999
# Dividing images and labels: 1730 / 1999
# Dividing images and labels: 1731 / 1999
# Dividing images and labels: 1732 / 1999
# Dividing images and labels: 1733 / 1999
# Dividing images and labels: 1734 / 1999
# Dividing images and labels: 1735 / 1999
# Dividing images and labels: 1736 / 1999
# Dividing images and labels: 1737 / 1999
# Dividing images and labels: 1738 / 1999
# Dividing images and labels: 1739 / 1999
# Dividing images and labels: 1740 / 1999
# Dividing images and labels: 1741 / 1999
# Dividing images and labels: 1742 / 1999
# Dividing images and labels: 1743 / 1999
# Dividing images and labels: 1744 / 1999
# Dividing images and labels: 1745 / 1999
# Dividing images and labels: 1746 / 1999
# Dividing images and labels: 1747 / 1999
# Dividing images and labels: 1748 / 1999
# Dividing images and labels: 1749 / 1999
# Dividing images and labels: 1750 / 1999
# Dividing images and labels: 1751 / 1999
# Dividing images and labels: 1752 / 1999
# Dividing images and labels: 1753 / 1999
# Dividing images and labels: 1754 / 1999
# Dividing images and labels: 1755 / 1999
# Dividing images and labels: 1756 / 1999
# Dividing images and labels: 1757 / 1999
# Dividing images and labels: 1758 / 1999
# Dividing images and labels: 1759 / 1999
# Dividing images and labels: 1760 / 1999
# Dividing images and labels: 1761 / 1999
# Dividing images and labels: 1762 / 1999
# Dividing images and labels: 1763 / 1999
# Dividing images and labels: 1764 / 1999
# Dividing images and labels: 1765 / 1999
# Dividing images and labels: 1766 / 1999
# Dividing images and labels: 1767 / 1999
# Dividing images and labels: 1768 / 1999
# Dividing images and labels: 1769 / 1999
# Dividing images and labels: 1770 / 1999
# Dividing images and labels: 1771 / 1999
# Dividing images and labels: 1772 / 1999
# Dividing images and labels: 1773 / 1999
# Dividing images and labels: 1774 / 1999
# Dividing images and labels: 1775 / 1999
# Dividing images and labels: 1776 / 1999
# Dividing images and labels: 1777 / 1999
# Dividing images and labels: 1778 / 1999
# Dividing images and labels: 1779 / 1999
# Dividing images and labels: 1780 / 1999
# Dividing images and labels: 1781 / 1999
# Dividing images and labels: 1782 / 1999
# Dividing images and labels: 1783 / 1999
# Dividing images and labels: 1784 / 1999
# Dividing images and labels: 1785 / 1999
# Dividing images and labels: 1786 / 1999
# Dividing images and labels: 1787 / 1999
# Dividing images and labels: 1788 / 1999
# Dividing images and labels: 1789 / 1999
# Dividing images and labels: 1790 / 1999
# Dividing images and labels: 1791 / 1999
# Dividing images and labels: 1792 / 1999
# Dividing images and labels: 1793 / 1999
# Dividing images and labels: 1794 / 1999
# Dividing images and labels: 1795 / 1999
# Dividing images and labels: 1796 / 1999
# Dividing images and labels: 1797 / 1999
# Dividing images and labels: 1798 / 1999
# Dividing images and labels: 1799 / 1999
# Dividing images and labels: 1800 / 1999
# Dividing images and labels: 1801 / 1999
# Dividing images and labels: 1802 / 1999
# Dividing images and labels: 1803 / 1999
# Dividing images and labels: 1804 / 1999
# Dividing images and labels: 1805 / 1999
# Dividing images and labels: 1806 / 1999
# Dividing images and labels: 1807 / 1999
# Dividing images and labels: 1808 / 1999
# Dividing images and labels: 1809 / 1999
# Dividing images and labels: 1810 / 1999
# Dividing images and labels: 1811 / 1999
# Dividing images and labels: 1812 / 1999
# Dividing images and labels: 1813 / 1999
# Dividing images and labels: 1814 / 1999
# Dividing images and labels: 1815 / 1999
# Dividing images and labels: 1816 / 1999
# Dividing images and labels: 1817 / 1999
# Dividing images and labels: 1818 / 1999
# Dividing images and labels: 1819 / 1999
# Dividing images and labels: 1820 / 1999
# Dividing images and labels: 1821 / 1999
# Dividing images and labels: 1822 / 1999
# Dividing images and labels: 1823 / 1999
# Dividing images and labels: 1824 / 1999
# Dividing images and labels: 1825 / 1999
# Dividing images and labels: 1826 / 1999
# Dividing images and labels: 1827 / 1999
# Dividing images and labels: 1828 / 1999
# Dividing images and labels: 1829 / 1999
# Dividing images and labels: 1830 / 1999
# Dividing images and labels: 1831 / 1999
# Dividing images and labels: 1832 / 1999
# Dividing images and labels: 1833 / 1999
# Dividing images and labels: 1834 / 1999
# Dividing images and labels: 1835 / 1999
# Dividing images and labels: 1836 / 1999
# Dividing images and labels: 1837 / 1999
# Dividing images and labels: 1838 / 1999
# Dividing images and labels: 1839 / 1999
# Dividing images and labels: 1840 / 1999
# Dividing images and labels: 1841 / 1999
# Dividing images and labels: 1842 / 1999
# Dividing images and labels: 1843 / 1999
# Dividing images and labels: 1844 / 1999
# Dividing images and labels: 1845 / 1999
# Dividing images and labels: 1846 / 1999
# Dividing images and labels: 1847 / 1999
# Dividing images and labels: 1848 / 1999
# Dividing images and labels: 1849 / 1999
# Dividing images and labels: 1850 / 1999
# Dividing images and labels: 1851 / 1999
# Dividing images and labels: 1852 / 1999
# Dividing images and labels: 1853 / 1999
# Dividing images and labels: 1854 / 1999
# Dividing images and labels: 1855 / 1999
# Dividing images and labels: 1856 / 1999
# Dividing images and labels: 1857 / 1999
# Dividing images and labels: 1858 / 1999
# Dividing images and labels: 1859 / 1999
# Dividing images and labels: 1860 / 1999
# Dividing images and labels: 1861 / 1999
# Dividing images and labels: 1862 / 1999
# Dividing images and labels: 1863 / 1999
# Dividing images and labels: 1864 / 1999
# Dividing images and labels: 1865 / 1999
# Dividing images and labels: 1866 / 1999
# Dividing images and labels: 1867 / 1999
# Dividing images and labels: 1868 / 1999
# Dividing images and labels: 1869 / 1999
# Dividing images and labels: 1870 / 1999
# Dividing images and labels: 1871 / 1999
# Dividing images and labels: 1872 / 1999
# Dividing images and labels: 1873 / 1999
# Dividing images and labels: 1874 / 1999
# Dividing images and labels: 1875 / 1999
# Dividing images and labels: 1876 / 1999
# Dividing images and labels: 1877 / 1999
# Dividing images and labels: 1878 / 1999
# Dividing images and labels: 1879 / 1999
# Dividing images and labels: 1880 / 1999
# Dividing images and labels: 1881 / 1999
# Dividing images and labels: 1882 / 1999
# Dividing images and labels: 1883 / 1999
# Dividing images and labels: 1884 / 1999
# Dividing images and labels: 1885 / 1999
# Dividing images and labels: 1886 / 1999
# Dividing images and labels: 1887 / 1999
# Dividing images and labels: 1888 / 1999
# Dividing images and labels: 1889 / 1999
# Dividing images and labels: 1890 / 1999
# Dividing images and labels: 1891 / 1999
# Dividing images and labels: 1892 / 1999
# Dividing images and labels: 1893 / 1999
# Dividing images and labels: 1894 / 1999
# Dividing images and labels: 1895 / 1999
# Dividing images and labels: 1896 / 1999
# Dividing images and labels: 1897 / 1999
# Dividing images and labels: 1898 / 1999
# Dividing images and labels: 1899 / 1999
# Dividing images and labels: 1900 / 1999
# Dividing images and labels: 1901 / 1999
# Dividing images and labels: 1902 / 1999
# Dividing images and labels: 1903 / 1999
# Dividing images and labels: 1904 / 1999
# Dividing images and labels: 1905 / 1999
# Dividing images and labels: 1906 / 1999
# Dividing images and labels: 1907 / 1999
# Dividing images and labels: 1908 / 1999
# Dividing images and labels: 1909 / 1999
# Dividing images and labels: 1910 / 1999
# Dividing images and labels: 1911 / 1999
# Dividing images and labels: 1912 / 1999
# Dividing images and labels: 1913 / 1999
# Dividing images and labels: 1914 / 1999
# Dividing images and labels: 1915 / 1999
# Dividing images and labels: 1916 / 1999
# Dividing images and labels: 1917 / 1999
# Dividing images and labels: 1918 / 1999
# Dividing images and labels: 1919 / 1999
# Dividing images and labels: 1920 / 1999
# Dividing images and labels: 1921 / 1999
# Dividing images and labels: 1922 / 1999
# Dividing images and labels: 1923 / 1999
# Dividing images and labels: 1924 / 1999
# Dividing images and labels: 1925 / 1999
# Dividing images and labels: 1926 / 1999
# Dividing images and labels: 1927 / 1999
# Dividing images and labels: 1928 / 1999
# Dividing images and labels: 1929 / 1999
# Dividing images and labels: 1930 / 1999
# Dividing images and labels: 1931 / 1999
# Dividing images and labels: 1932 / 1999
# Dividing images and labels: 1933 / 1999
# Dividing images and labels: 1934 / 1999
# Dividing images and labels: 1935 / 1999
# Dividing images and labels: 1936 / 1999
# Dividing images and labels: 1937 / 1999
# Dividing images and labels: 1938 / 1999
# Dividing images and labels: 1939 / 1999
# Dividing images and labels: 1940 / 1999
# Dividing images and labels: 1941 / 1999
# Dividing images and labels: 1942 / 1999
# Dividing images and labels: 1943 / 1999
# Dividing images and labels: 1944 / 1999
# Dividing images and labels: 1945 / 1999
# Dividing images and labels: 1946 / 1999
# Dividing images and labels: 1947 / 1999
# Dividing images and labels: 1948 / 1999
# Dividing images and labels: 1949 / 1999
# Dividing images and labels: 1950 / 1999
# Dividing images and labels: 1951 / 1999
# Dividing images and labels: 1952 / 1999
# Dividing images and labels: 1953 / 1999
# Dividing images and labels: 1954 / 1999
# Dividing images and labels: 1955 / 1999
# Dividing images and labels: 1956 / 1999
# Dividing images and labels: 1957 / 1999
# Dividing images and labels: 1958 / 1999
# Dividing images and labels: 1959 / 1999
# Dividing images and labels: 1960 / 1999
# Dividing images and labels: 1961 / 1999
# Dividing images and labels: 1962 / 1999
# Dividing images and labels: 1963 / 1999
# Dividing images and labels: 1964 / 1999
# Dividing images and labels: 1965 / 1999
# Dividing images and labels: 1966 / 1999
# Dividing images and labels: 1967 / 1999
# Dividing images and labels: 1968 / 1999
# Dividing images and labels: 1969 / 1999
# Dividing images and labels: 1970 / 1999
# Dividing images and labels: 1971 / 1999
# Dividing images and labels: 1972 / 1999
# Dividing images and labels: 1973 / 1999
# Dividing images and labels: 1974 / 1999
# Dividing images and labels: 1975 / 1999
# Dividing images and labels: 1976 / 1999
# Dividing images and labels: 1977 / 1999
# Dividing images and labels: 1978 / 1999
# Dividing images and labels: 1979 / 1999
# Dividing images and labels: 1980 / 1999
# Dividing images and labels: 1981 / 1999
# Dividing images and labels: 1982 / 1999
# Dividing images and labels: 1983 / 1999
# Dividing images and labels: 1984 / 1999
# Dividing images and labels: 1985 / 1999
# Dividing images and labels: 1986 / 1999
# Dividing images and labels: 1987 / 1999
# Dividing images and labels: 1988 / 1999
# Dividing images and labels: 1989 / 1999
# Dividing images and labels: 1990 / 1999
# Dividing images and labels: 1991 / 1999
# Dividing images and labels: 1992 / 1999
# Dividing images and labels: 1993 / 1999
# Dividing images and labels: 1994 / 1999
# Dividing images and labels: 1995 / 1999
# Dividing images and labels: 1996 / 1999
# Dividing images and labels: 1997 / 1999
# Dividing images and labels: 1998 / 1999
# Dividing images and labels: 1999 / 1999

# %%
ellip_fill(train_label_folder, train_label_folder)
# Out:
# Ellip filling: 1 / 999
# Ellip filling: 2 / 999
# Ellip filling: 3 / 999
# Ellip filling: 922 / 999
# Ellip filling: 923 / 999
# Ellip filling: 924 / 999
# Ellip filling: 925 / 999
# Ellip filling: 926 / 999
# Ellip filling: 927 / 999
# Ellip filling: 928 / 999
# Ellip filling: 929 / 999
# Ellip filling: 930 / 999
# Ellip filling: 931 / 999
# Ellip filling: 932 / 999
# Ellip filling: 933 / 999
# Ellip filling: 934 / 999
# Ellip filling: 935 / 999
# Ellip filling: 936 / 999
# Ellip filling: 937 / 999
# Ellip filling: 938 / 999
# Ellip filling: 939 / 999
# Ellip filling: 940 / 999
# Ellip filling: 941 / 999
# Ellip filling: 942 / 999
# Ellip filling: 943 / 999
# Ellip filling: 944 / 999
# Ellip filling: 945 / 999
# Ellip filling: 946 / 999
# Ellip filling: 947 / 999
# Ellip filling: 948 / 999
# Ellip filling: 949 / 999
# Ellip filling: 950 / 999
# Ellip filling: 951 / 999
# Ellip filling: 952 / 999
# Ellip filling: 953 / 999
# Ellip filling: 954 / 999
# Ellip filling: 955 / 999
# Ellip filling: 956 / 999
# Ellip filling: 957 / 999
# Ellip filling: 958 / 999
# Ellip filling: 959 / 999
# Ellip filling: 960 / 999
# Ellip filling: 961 / 999
# Ellip filling: 962 / 999
# Ellip filling: 963 / 999
# Ellip filling: 964 / 999
# Ellip filling: 965 / 999
# Ellip filling: 966 / 999
# Ellip filling: 967 / 999
# Ellip filling: 968 / 999
# Ellip filling: 969 / 999
# Ellip filling: 970 / 999
# Ellip filling: 971 / 999
# Ellip filling: 972 / 999
# Ellip filling: 973 / 999
# Ellip filling: 974 / 999
# Ellip filling: 975 / 999
# Ellip filling: 976 / 999
# Ellip filling: 977 / 999
# Ellip filling: 978 / 999
# Ellip filling: 979 / 999
# Ellip filling: 980 / 999
# Ellip filling: 981 / 999
# Ellip filling: 982 / 999
# Ellip filling: 983 / 999
# Ellip filling: 984 / 999
# Ellip filling: 985 / 999
# Ellip filling: 986 / 999
# Ellip filling: 987 / 999
# Ellip filling: 988 / 999
# Ellip filling: 989 / 999
# Ellip filling: 990 / 999
# Ellip filling: 991 / 999
# Ellip filling: 992 / 999
# Ellip filling: 993 / 999
# Ellip filling: 994 / 999
# Ellip filling: 995 / 999
# Ellip filling: 996 / 999
# Ellip filling: 997 / 999
# Ellip filling: 998 / 999
# Ellip filling: 999 / 999

# %%
val_img_folder = '/kaggle/working/data/validation/images/'
val_label_folder = '/kaggle/working/data/validation/labels/'
os.makedirs(val_img_folder)
os.makedirs(val_label_folder)

dirs = os.listdir(train_img_folder)
l = len(dirs)
val_l= round(0.2*l)
random.shuffle(dirs)

for i in range(val_l):
    print("Dividing the train and val set: %d / %d" % (i+1, val_l))
    img_name = dirs[i]
    label_name = img_name[:-4] + '_Annotation.png'

    img_path = train_img_folder + img_name
    label_path = train_label_folder + label_name

    img_save_path = val_img_folder + img_name
    label_save_path = val_label_folder + label_name

    img = cv2.imread(img_path, 0)
    label = cv2.imread(label_path, 0)

    cv2.imwrite(img_save_path, img)
    cv2.imwrite(label_save_path, label)

    # Remove validation images and labels from '../data/train/images' and '../data/train/labels'
    os.remove(img_path)
    os.remove(label_path)
# Out:
# Dividing the train and val set: 1 / 200
# Dividing the train and val set: 2 / 200
# Dividing the train and val set: 3 / 200
# Dividing the train and val set: 4 / 200
# Dividing the train and val set: 5 / 200
# Dividing the train and val set: 6 / 200
# Dividing the train and val set: 7 / 200
# Dividing the train and val set: 8 / 200
# Dividing the train and val set: 9 / 200
# Dividing the train and val set: 10 / 200
# Dividing the train and val set: 11 / 200
# Dividing the train and val set: 12 / 200
# Dividing the train and val set: 13 / 200
# Dividing the train and val set: 14 / 200
# Dividing the train and val set: 15 / 200
# Dividing the train and val set: 16 / 200
# Dividing the train and val set: 17 / 200
# Dividing the train and val set: 18 / 200
# Dividing the train and val set: 19 / 200
# Dividing the train and val set: 20 / 200
# Dividing the train and val set: 21 / 200
# Dividing the train and val set: 22 / 200
# Dividing the train and val set: 23 / 200
# Dividing the train and val set: 24 / 200
# Dividing the train and val set: 25 / 200
# Dividing the train and val set: 26 / 200
# Dividing the train and val set: 27 / 200
# Dividing the train and val set: 28 / 200
# Dividing the train and val set: 29 / 200
# Dividing the train and val set: 30 / 200
# Dividing the train and val set: 31 / 200
# Dividing the train and val set: 32 / 200
# Dividing the train and val set: 33 / 200
# Dividing the train and val set: 34 / 200
# Dividing the train and val set: 35 / 200
# Dividing the train and val set: 36 / 200
# Dividing the train and val set: 37 / 200
# Dividing the train and val set: 38 / 200
# Dividing the train and val set: 39 / 200
# Dividing the train and val set: 40 / 200
# Dividing the train and val set: 41 / 200
# Dividing the train and val set: 42 / 200
# Dividing the train and val set: 43 / 200
# Dividing the train and val set: 44 / 200
# Dividing the train and val set: 45 / 200
# Dividing the train and val set: 46 / 200
# Dividing the train and val set: 47 / 200
# Dividing the train and val set: 48 / 200
# Dividing the train and val set: 49 / 200
# Dividing the train and val set: 50 / 200
# Dividing the train and val set: 51 / 200
# Dividing the train and val set: 52 / 200
# Dividing the train and val set: 53 / 200
# Dividing the train and val set: 54 / 200
# Dividing the train and val set: 55 / 200
# Dividing the train and val set: 56 / 200
# Dividing the train and val set: 57 / 200
# Dividing the train and val set: 58 / 200
# Dividing the train and val set: 59 / 200
# Dividing the train and val set: 60 / 200
# Dividing the train and val set: 61 / 200
# Dividing the train and val set: 62 / 200
# Dividing the train and val set: 63 / 200
# Dividing the train and val set: 64 / 200
# Dividing the train and val set: 65 / 200
# Dividing the train and val set: 66 / 200
# Dividing the train and val set: 67 / 200
# Dividing the train and val set: 68 / 200
# Dividing the train and val set: 69 / 200
# Dividing the train and val set: 70 / 200
# Dividing the train and val set: 71 / 200
# Dividing the train and val set: 72 / 200
# Dividing the train and val set: 73 / 200
# Dividing the train and val set: 74 / 200
# Dividing the train and val set: 75 / 200
# Dividing the train and val set: 76 / 200
# Dividing the train and val set: 77 / 200
# Dividing the train and val set: 78 / 200
# Dividing the train and val set: 79 / 200
# Dividing the train and val set: 80 / 200
# Dividing the train and val set: 81 / 200
# Dividing the train and val set: 82 / 200
# Dividing the train and val set: 83 / 200
# Dividing the train and val set: 84 / 200
# Dividing the train and val set: 85 / 200
# Dividing the train and val set: 86 / 200
# Dividing the train and val set: 87 / 200
# Dividing the train and val set: 88 / 200
# Dividing the train and val set: 89 / 200
# Dividing the train and val set: 90 / 200
# Dividing the train and val set: 91 / 200
# Dividing the train and val set: 92 / 200
# Dividing the train and val set: 93 / 200
# Dividing the train and val set: 94 / 200
# Dividing the train and val set: 95 / 200
# Dividing the train and val set: 96 / 200
# Dividing the train and val set: 97 / 200
# Dividing the train and val set: 98 / 200
# Dividing the train and val set: 99 / 200
# Dividing the train and val set: 100 / 200
# Dividing the train and val set: 101 / 200
# Dividing the train and val set: 102 / 200
# Dividing the train and val set: 103 / 200
# Dividing the train and val set: 104 / 200
# Dividing the train and val set: 105 / 200
# Dividing the train and val set: 106 / 200
# Dividing the train and val set: 107 / 200
# Dividing the train and val set: 108 / 200
# Dividing the train and val set: 109 / 200
# Dividing the train and val set: 110 / 200
# Dividing the train and val set: 111 / 200
# Dividing the train and val set: 112 / 200
# Dividing the train and val set: 113 / 200
# Dividing the train and val set: 114 / 200
# Dividing the train and val set: 115 / 200
# Dividing the train and val set: 116 / 200
# Dividing the train and val set: 117 / 200
# Dividing the train and val set: 118 / 200
# Dividing the train and val set: 119 / 200
# Dividing the train and val set: 120 / 200
# Dividing the train and val set: 121 / 200
# Dividing the train and val set: 122 / 200
# Dividing the train and val set: 123 / 200
# Dividing the train and val set: 124 / 200
# Dividing the train and val set: 125 / 200
# Dividing the train and val set: 126 / 200
# Dividing the train and val set: 127 / 200
# Dividing the train and val set: 128 / 200
# Dividing the train and val set: 129 / 200
# Dividing the train and val set: 130 / 200
# Dividing the train and val set: 131 / 200
# Dividing the train and val set: 132 / 200
# Dividing the train and val set: 133 / 200
# Dividing the train and val set: 134 / 200
# Dividing the train and val set: 135 / 200
# Dividing the train and val set: 136 / 200
# Dividing the train and val set: 137 / 200
# Dividing the train and val set: 138 / 200
# Dividing the train and val set: 139 / 200
# Dividing the train and val set: 140 / 200
# Dividing the train and val set: 141 / 200
# Dividing the train and val set: 142 / 200
# Dividing the train and val set: 143 / 200
# Dividing the train and val set: 144 / 200
# Dividing the train and val set: 145 / 200
# Dividing the train and val set: 146 / 200
# Dividing the train and val set: 147 / 200
# Dividing the train and val set: 148 / 200
# Dividing the train and val set: 149 / 200
# Dividing the train and val set: 150 / 200
# Dividing the train and val set: 151 / 200
# Dividing the train and val set: 152 / 200
# Dividing the train and val set: 153 / 200
# Dividing the train and val set: 154 / 200
# Dividing the train and val set: 155 / 200
# Dividing the train and val set: 156 / 200
# Dividing the train and val set: 157 / 200
# Dividing the train and val set: 158 / 200
# Dividing the train and val set: 159 / 200
# Dividing the train and val set: 160 / 200
# Dividing the train and val set: 161 / 200
# Dividing the train and val set: 162 / 200
# Dividing the train and val set: 163 / 200
# Dividing the train and val set: 164 / 200
# Dividing the train and val set: 165 / 200
# Dividing the train and val set: 166 / 200
# Dividing the train and val set: 167 / 200
# Dividing the train and val set: 168 / 200
# Dividing the train and val set: 169 / 200
# Dividing the train and val set: 170 / 200
# Dividing the train and val set: 171 / 200
# Dividing the train and val set: 172 / 200
# Dividing the train and val set: 173 / 200
# Dividing the train and val set: 174 / 200
# Dividing the train and val set: 175 / 200
# Dividing the train and val set: 176 / 200
# Dividing the train and val set: 177 / 200
# Dividing the train and val set: 178 / 200
# Dividing the train and val set: 179 / 200
# Dividing the train and val set: 180 / 200
# Dividing the train and val set: 181 / 200
# Dividing the train and val set: 182 / 200
# Dividing the train and val set: 183 / 200
# Dividing the train and val set: 184 / 200
# Dividing the train and val set: 185 / 200
# Dividing the train and val set: 186 / 200
# Dividing the train and val set: 187 / 200
# Dividing the train and val set: 188 / 200
# Dividing the train and val set: 189 / 200
# Dividing the train and val set: 190 / 200
# Dividing the train and val set: 191 / 200
# Dividing the train and val set: 192 / 200
# Dividing the train and val set: 193 / 200
# Dividing the train and val set: 194 / 200
# Dividing the train and val set: 195 / 200
# Dividing the train and val set: 196 / 200
# Dividing the train and val set: 197 / 200
# Dividing the train and val set: 198 / 200
# Dividing the train and val set: 199 / 200
# Dividing the train and val set: 200 / 200

# %%
pixel_size_hc_file = '/kaggle/input/fetal-head/training_set_pixel_size_and_HC.csv'
val_pixel_size_hc_save = '/kaggle/working/data/validation/val_set_pixel_size_and_HC.csv'
p_size_hc = pd.read_csv(pixel_size_hc_file)

fn = p_size_hc['filename'].values
ps = p_size_hc['pixel size'].values
hc = p_size_hc['head circumference (mm)'].values

new_psize_hc = pd.DataFrame({'pixel size':ps,'head circumference (mm)':hc},index=fn)

val_psize_hc = pd.DataFrame(new_psize_hc,index=dirs[0:val_l])

val_fn = val_psize_hc.index
val_ps = val_psize_hc['pixel size'].values
val_hc = val_psize_hc['head circumference (mm)'].values

val_psize_hc = pd.DataFrame({'filename':val_fn, 'pixel size':val_ps, 'head circumference (mm)':val_hc})
val_psize_hc.to_csv(val_pixel_size_hc_save,index=False)

# %%
# Data augumentation in train set
train_augu_img_folder = '/kaggle/working/data/train/augu_images/'
train_augu_label_folder = '/kaggle/working/data/train/augu_labels/'
os.makedirs(train_augu_img_folder)
os.makedirs(train_augu_label_folder)

# %%
# Image augumentation
img_augumentation(train_img_folder,train_augu_img_folder,data="image")
# Out:
# image augumentation: 1 / 799
# image augumentation: 2 / 799
# image augumentation: 3 / 799
# image augumentation: 4 / 799
# image augumentation: 5 / 799
# image augumentation: 6 / 799
# image augumentation: 7 / 799
# image augumentation: 8 / 799
# image augumentation: 9 / 799
# image augumentation: 10 / 799
# image augumentation: 11 / 799
# image augumentation: 12 / 799
# image augumentation: 13 / 799
# image augumentation: 14 / 799
# image augumentation: 15 / 799
# image augumentation: 16 / 799
# image augumentation: 17 / 799
# image augumentation: 18 / 799
# image augumentation: 19 / 799
# image augumentation: 20 / 799
# image augumentation: 21 / 799
# image augumentation: 22 / 799
# image augumentation: 23 / 799
# image augumentation: 24 / 799
# image augumentation: 25 / 799
# image augumentation: 26 / 799
# image augumentation: 792 / 799
# image augumentation: 793 / 799
# image augumentation: 794 / 799
# image augumentation: 795 / 799
# image augumentation: 796 / 799
# image augumentation: 797 / 799
# image augumentation: 798 / 799
# image augumentation: 799 / 799
# Images augumentation finished!

# %%
# Label augumentation
img_augumentation(train_label_folder, train_augu_label_folder, data="label")
# Out:
# label augumentation: 1 / 799
# label augumentation: 2 / 799
# label augumentation: 3 / 799
# label augumentation: 4 / 799
# label augumentation: 5 / 799
# label augumentation: 6 / 799
# label augumentation: 7 / 799
# label augumentation: 8 / 799
# label augumentation: 9 / 799
# label augumentation: 10 / 799
# label augumentation: 11 / 799
# label augumentation: 12 / 799
# label augumentation: 13 / 799
# label augumentation: 14 / 799
# label augumentation: 15 / 799
# label augumentation: 16 / 799
# label augumentation: 17 / 799
# label augumentation: 18 / 799
# label augumentation: 19 / 799
# label augumentation: 20 / 799
# label augumentation: 21 / 799
# label augumentation: 22 / 799
# label augumentation: 23 / 799
# label augumentation: 24 / 799
# label augumentation: 25 / 799
# label augumentation: 26 / 799
# label augumentation: 27 / 799
# label augumentation: 28 / 799
# label augumentation: 29 / 799
# label augumentation: 30 / 799
# label augumentation: 31 / 799
# label augumentation: 32 / 799
# label augumentation: 33 / 799
# label augumentation: 34 / 799
# label augumentation: 35 / 799
# label augumentation: 36 / 799
# label augumentation: 37 / 799
# label augumentation: 38 / 799
# label augumentation: 39 / 799
# label augumentation: 40 / 799
# label augumentation: 41 / 799
# label augumentation: 42 / 799
# label augumentation: 43 / 799
# label augumentation: 44 / 799
# label augumentation: 45 / 799
# label augumentation: 46 / 799
# label augumentation: 47 / 799
# label augumentation: 48 / 799
# label augumentation: 49 / 799
# label augumentation: 50 / 799
# label augumentation: 51 / 799
# label augumentation: 52 / 799
# label augumentation: 53 / 799
# label augumentation: 54 / 799
# label augumentation: 55 / 799
# label augumentation: 56 / 799
# label augumentation: 57 / 799
# label augumentation: 58 / 799
# label augumentation: 59 / 799
# label augumentation: 60 / 799
# label augumentation: 61 / 799
# label augumentation: 62 / 799
# label augumentation: 63 / 799
# label augumentation: 64 / 799
# label augumentation: 65 / 799
# label augumentation: 66 / 799
# label augumentation: 67 / 799
# label augumentation: 68 / 799
# label augumentation: 69 / 799
# label augumentation: 70 / 799
# label augumentation: 71 / 799
# label augumentation: 72 / 799
# label augumentation: 73 / 799
# label augumentation: 74 / 799
# label augumentation: 75 / 799
# label augumentation: 76 / 799
# label augumentation: 77 / 799
# label augumentation: 78 / 799
# label augumentation: 79 / 799
# label augumentation: 80 / 799
# label augumentation: 81 / 799
# label augumentation: 82 / 799
# label augumentation: 83 / 799
# label augumentation: 84 / 799
# label augumentation: 85 / 799
# label augumentation: 86 / 799
# label augumentation: 87 / 799
# label augumentation: 88 / 799
# label augumentation: 89 / 799
# label augumentation: 90 / 799
# label augumentation: 91 / 799
# label augumentation: 92 / 799
# label augumentation: 93 / 799
# label augumentation: 94 / 799
# label augumentation: 95 / 799
# label augumentation: 96 / 799
# label augumentation: 97 / 799
# label augumentation: 98 / 799
# label augumentation: 99 / 799
# label augumentation: 100 / 799
# label augumentation: 101 / 799
# label augumentation: 102 / 799
# label augumentation: 103 / 799
# label augumentation: 104 / 799
# label augumentation: 105 / 799
# label augumentation: 106 / 799
# label augumentation: 107 / 799
# label augumentation: 108 / 799
# label augumentation: 109 / 799
# label augumentation: 110 / 799
# label augumentation: 111 / 799
# label augumentation: 112 / 799
# label augumentation: 113 / 799
# label augumentation: 114 / 799
# label augumentation: 115 / 799
# label augumentation: 116 / 799
# label augumentation: 117 / 799
# label augumentation: 118 / 799
# label augumentation: 119 / 799
# label augumentation: 120 / 799
# label augumentation: 121 / 799
# label augumentation: 122 / 799
# label augumentation: 123 / 799
# label augumentation: 124 / 799
# label augumentation: 125 / 799
# label augumentation: 126 / 799
# label augumentation: 127 / 799
# label augumentation: 128 / 799
# label augumentation: 129 / 799
# label augumentation: 130 / 799
# label augumentation: 131 / 799
# label augumentation: 132 / 799
# label augumentation: 133 / 799
# label augumentation: 134 / 799
# label augumentation: 135 / 799
# label augumentation: 136 / 799
# label augumentation: 137 / 799
# label augumentation: 138 / 799
# label augumentation: 139 / 799
# label augumentation: 140 / 799
# label augumentation: 141 / 799
# label augumentation: 142 / 799
# label augumentation: 143 / 799
# label augumentation: 144 / 799
# label augumentation: 145 / 799
# label augumentation: 146 / 799
# label augumentation: 147 / 799
# label augumentation: 148 / 799
# label augumentation: 149 / 799
# label augumentation: 150 / 799
# label augumentation: 151 / 799
# label augumentation: 152 / 799
# label augumentation: 153 / 799
# label augumentation: 154 / 799
# label augumentation: 155 / 799
# label augumentation: 156 / 799
# label augumentation: 157 / 799
# label augumentation: 158 / 799
# label augumentation: 159 / 799
# label augumentation: 160 / 799
# label augumentation: 161 / 799
# label augumentation: 162 / 799
# label augumentation: 163 / 799
# label augumentation: 164 / 799
# label augumentation: 165 / 799
# label augumentation: 166 / 799
# label augumentation: 167 / 799
# label augumentation: 168 / 799
# label augumentation: 169 / 799
# label augumentation: 170 / 799
# label augumentation: 171 / 799
# label augumentation: 172 / 799
# label augumentation: 173 / 799
# label augumentation: 174 / 799
# label augumentation: 175 / 799
# label augumentation: 176 / 799
# label augumentation: 177 / 799
# label augumentation: 178 / 799
# label augumentation: 179 / 799
# label augumentation: 180 / 799
# label augumentation: 181 / 799
# label augumentation: 182 / 799
# label augumentation: 183 / 799
# label augumentation: 184 / 799
# label augumentation: 185 / 799
# label augumentation: 186 / 799
# label augumentation: 187 / 799
# label augumentation: 188 / 799
# label augumentation: 189 / 799
# label augumentation: 190 / 799
# label augumentation: 191 / 799
# label augumentation: 192 / 799
# label augumentation: 193 / 799
# label augumentation: 194 / 799
# label augumentation: 195 / 799
# label augumentation: 196 / 799
# label augumentation: 197 / 799
# label augumentation: 198 / 799
# label augumentation: 199 / 799
# label augumentation: 200 / 799
# label augumentation: 201 / 799
# label augumentation: 202 / 799
# label augumentation: 203 / 799
# label augumentation: 204 / 799
# label augumentation: 205 / 799
# label augumentation: 206 / 799
# label augumentation: 207 / 799
# label augumentation: 208 / 799
# label augumentation: 209 / 799
# label augumentation: 210 / 799
# label augumentation: 211 / 799
# label augumentation: 212 / 799
# label augumentation: 213 / 799
# label augumentation: 214 / 799
# label augumentation: 215 / 799
# label augumentation: 216 / 799
# label augumentation: 217 / 799
# label augumentation: 218 / 799
# label augumentation: 219 / 799
# label augumentation: 220 / 799
# label augumentation: 221 / 799
# label augumentation: 222 / 799
# label augumentation: 223 / 799
# label augumentation: 224 / 799
# label augumentation: 225 / 799
# label augumentation: 226 / 799
# label augumentation: 227 / 799
# label augumentation: 228 / 799
# label augumentation: 229 / 799
# label augumentation: 230 / 799
# label augumentation: 231 / 799
# label augumentation: 232 / 799
# label augumentation: 233 / 799
# label augumentation: 234 / 799
# label augumentation: 235 / 799
# label augumentation: 236 / 799
# label augumentation: 237 / 799
# label augumentation: 238 / 799
# label augumentation: 239 / 799
# label augumentation: 240 / 799
# label augumentation: 241 / 799
# label augumentation: 242 / 799
# label augumentation: 243 / 799
# label augumentation: 244 / 799
# label augumentation: 245 / 799
# label augumentation: 246 / 799
# label augumentation: 247 / 799
# label augumentation: 248 / 799
# label augumentation: 249 / 799
# label augumentation: 250 / 799
# label augumentation: 251 / 799
# label augumentation: 252 / 799
# label augumentation: 253 / 799
# label augumentation: 254 / 799
# label augumentation: 255 / 799
# label augumentation: 256 / 799
# label augumentation: 257 / 799
# label augumentation: 258 / 799
# label augumentation: 259 / 799
# label augumentation: 260 / 799
# label augumentation: 261 / 799
# label augumentation: 262 / 799
# label augumentation: 263 / 799
# label augumentation: 264 / 799
# label augumentation: 265 / 799
# label augumentation: 266 / 799
# label augumentation: 267 / 799
# label augumentation: 268 / 799
# label augumentation: 269 / 799
# label augumentation: 270 / 799
# label augumentation: 271 / 799
# label augumentation: 272 / 799
# label augumentation: 273 / 799
# label augumentation: 274 / 799
# label augumentation: 275 / 799
# label augumentation: 276 / 799
# label augumentation: 277 / 799
# label augumentation: 278 / 799
# label augumentation: 279 / 799
# label augumentation: 280 / 799
# label augumentation: 281 / 799
# label augumentation: 282 / 799
# label augumentation: 283 / 799
# label augumentation: 284 / 799
# label augumentation: 285 / 799
# label augumentation: 286 / 799
# label augumentation: 287 / 799
# label augumentation: 288 / 799
# label augumentation: 289 / 799
# label augumentation: 290 / 799
# label augumentation: 291 / 799
# label augumentation: 292 / 799
# label augumentation: 293 / 799
# label augumentation: 294 / 799
# label augumentation: 295 / 799
# label augumentation: 296 / 799
# label augumentation: 297 / 799
# label augumentation: 298 / 799
# label augumentation: 299 / 799
# label augumentation: 300 / 799
# label augumentation: 301 / 799
# label augumentation: 302 / 799
# label augumentation: 303 / 799
# label augumentation: 304 / 799
# label augumentation: 305 / 799
# label augumentation: 306 / 799
# label augumentation: 307 / 799
# label augumentation: 308 / 799
# label augumentation: 309 / 799
# label augumentation: 310 / 799
# label augumentation: 311 / 799
# label augumentation: 312 / 799
# label augumentation: 313 / 799
# label augumentation: 314 / 799
# label augumentation: 315 / 799
# label augumentation: 316 / 799
# label augumentation: 317 / 799
# label augumentation: 318 / 799
# label augumentation: 319 / 799
# label augumentation: 320 / 799
# label augumentation: 321 / 799
# label augumentation: 322 / 799
# label augumentation: 323 / 799
# label augumentation: 324 / 799
# label augumentation: 325 / 799
# label augumentation: 326 / 799
# label augumentation: 327 / 799
# label augumentation: 328 / 799
# label augumentation: 329 / 799
# label augumentation: 330 / 799
# label augumentation: 331 / 799
# label augumentation: 332 / 799
# label augumentation: 333 / 799
# label augumentation: 334 / 799
# label augumentation: 335 / 799
# label augumentation: 336 / 799
# label augumentation: 337 / 799
# label augumentation: 338 / 799
# label augumentation: 339 / 799
# label augumentation: 340 / 799
# label augumentation: 341 / 799
# label augumentation: 342 / 799
# label augumentation: 343 / 799
# label augumentation: 344 / 799
# label augumentation: 345 / 799
# label augumentation: 346 / 799
# label augumentation: 347 / 799
# label augumentation: 348 / 799
# label augumentation: 349 / 799
# label augumentation: 350 / 799
# label augumentation: 351 / 799
# label augumentation: 352 / 799
# label augumentation: 353 / 799
# label augumentation: 354 / 799
# label augumentation: 355 / 799
# label augumentation: 356 / 799
# label augumentation: 357 / 799
# label augumentation: 358 / 799
# label augumentation: 359 / 799
# label augumentation: 360 / 799
# label augumentation: 361 / 799
# label augumentation: 362 / 799
# label augumentation: 363 / 799
# label augumentation: 364 / 799
# label augumentation: 365 / 799
# label augumentation: 366 / 799
# label augumentation: 367 / 799
# label augumentation: 368 / 799
# label augumentation: 369 / 799
# label augumentation: 370 / 799
# label augumentation: 371 / 799
# label augumentation: 372 / 799
# label augumentation: 373 / 799
# label augumentation: 374 / 799
# label augumentation: 375 / 799
# label augumentation: 376 / 799
# label augumentation: 377 / 799
# label augumentation: 378 / 799
# label augumentation: 379 / 799
# label augumentation: 380 / 799
# label augumentation: 381 / 799
# label augumentation: 382 / 799
# label augumentation: 383 / 799
# label augumentation: 384 / 799
# label augumentation: 385 / 799
# label augumentation: 386 / 799
# label augumentation: 387 / 799
# label augumentation: 388 / 799
# label augumentation: 389 / 799
# label augumentation: 390 / 799
# label augumentation: 391 / 799
# label augumentation: 392 / 799
# label augumentation: 393 / 799
# label augumentation: 394 / 799
# label augumentation: 395 / 799
# label augumentation: 396 / 799
# label augumentation: 397 / 799
# label augumentation: 398 / 799
# label augumentation: 399 / 799
# label augumentation: 400 / 799
# label augumentation: 401 / 799
# label augumentation: 402 / 799
# label augumentation: 403 / 799
# label augumentation: 404 / 799
# label augumentation: 405 / 799
# label augumentation: 406 / 799
# label augumentation: 407 / 799
# label augumentation: 408 / 799
# label augumentation: 409 / 799
# label augumentation: 410 / 799
# label augumentation: 411 / 799
# label augumentation: 412 / 799
# label augumentation: 413 / 799
# label augumentation: 414 / 799
# label augumentation: 415 / 799
# label augumentation: 416 / 799
# label augumentation: 417 / 799
# label augumentation: 418 / 799
# label augumentation: 419 / 799
# label augumentation: 420 / 799
# label augumentation: 421 / 799
# label augumentation: 422 / 799
# label augumentation: 423 / 799
# label augumentation: 424 / 799
# label augumentation: 425 / 799
# label augumentation: 426 / 799
# label augumentation: 427 / 799
# label augumentation: 428 / 799
# label augumentation: 429 / 799
# label augumentation: 430 / 799
# label augumentation: 431 / 799
# label augumentation: 432 / 799
# label augumentation: 433 / 799
# label augumentation: 434 / 799
# label augumentation: 435 / 799
# label augumentation: 436 / 799
# label augumentation: 437 / 799
# label augumentation: 438 / 799
# label augumentation: 439 / 799
# label augumentation: 440 / 799
# label augumentation: 441 / 799
# label augumentation: 442 / 799
# label augumentation: 443 / 799
# label augumentation: 444 / 799
# label augumentation: 445 / 799
# label augumentation: 446 / 799
# label augumentation: 447 / 799
# label augumentation: 448 / 799
# label augumentation: 449 / 799
# label augumentation: 450 / 799
# label augumentation: 451 / 799
# label augumentation: 452 / 799
# label augumentation: 453 / 799
# label augumentation: 454 / 799
# label augumentation: 455 / 799
# label augumentation: 456 / 799
# label augumentation: 457 / 799
# label augumentation: 458 / 799
# label augumentation: 459 / 799
# label augumentation: 460 / 799
# label augumentation: 461 / 799
# label augumentation: 462 / 799
# label augumentation: 463 / 799
# label augumentation: 464 / 799
# label augumentation: 465 / 799
# label augumentation: 466 / 799
# label augumentation: 467 / 799
# label augumentation: 468 / 799
# label augumentation: 469 / 799
# label augumentation: 470 / 799
# label augumentation: 471 / 799
# label augumentation: 472 / 799
# label augumentation: 473 / 799
# label augumentation: 474 / 799
# label augumentation: 475 / 799
# label augumentation: 476 / 799
# label augumentation: 477 / 799
# label augumentation: 478 / 799
# label augumentation: 479 / 799
# label augumentation: 480 / 799
# label augumentation: 481 / 799
# label augumentation: 482 / 799
# label augumentation: 483 / 799
# label augumentation: 484 / 799
# label augumentation: 485 / 799
# label augumentation: 486 / 799
# label augumentation: 487 / 799
# label augumentation: 488 / 799
# label augumentation: 489 / 799
# label augumentation: 490 / 799
# label augumentation: 491 / 799
# label augumentation: 492 / 799
# label augumentation: 493 / 799
# label augumentation: 494 / 799
# label augumentation: 495 / 799
# label augumentation: 496 / 799
# label augumentation: 497 / 799
# label augumentation: 498 / 799
# label augumentation: 499 / 799
# label augumentation: 500 / 799
# label augumentation: 501 / 799
# label augumentation: 502 / 799
# label augumentation: 503 / 799
# label augumentation: 504 / 799
# label augumentation: 505 / 799
# label augumentation: 506 / 799
# label augumentation: 507 / 799
# label augumentation: 508 / 799
# label augumentation: 509 / 799
# label augumentation: 510 / 799
# label augumentation: 511 / 799
# label augumentation: 512 / 799
# label augumentation: 513 / 799
# label augumentation: 514 / 799
# label augumentation: 515 / 799
# label augumentation: 516 / 799
# label augumentation: 517 / 799
# label augumentation: 518 / 799
# label augumentation: 519 / 799
# label augumentation: 520 / 799
# label augumentation: 521 / 799
# label augumentation: 522 / 799
# label augumentation: 523 / 799
# label augumentation: 524 / 799
# label augumentation: 525 / 799
# label augumentation: 526 / 799
# label augumentation: 527 / 799
# label augumentation: 528 / 799
# label augumentation: 529 / 799
# label augumentation: 530 / 799
# label augumentation: 531 / 799
# label augumentation: 532 / 799
# label augumentation: 533 / 799
# label augumentation: 534 / 799
# label augumentation: 535 / 799
# label augumentation: 536 / 799
# label augumentation: 537 / 799
# label augumentation: 538 / 799
# label augumentation: 539 / 799
# label augumentation: 540 / 799
# label augumentation: 541 / 799
# label augumentation: 542 / 799
# label augumentation: 543 / 799
# label augumentation: 544 / 799
# label augumentation: 545 / 799
# label augumentation: 546 / 799
# label augumentation: 547 / 799
# label augumentation: 548 / 799
# label augumentation: 549 / 799
# label augumentation: 550 / 799
# label augumentation: 551 / 799
# label augumentation: 552 / 799
# label augumentation: 553 / 799
# label augumentation: 554 / 799
# label augumentation: 555 / 799
# label augumentation: 556 / 799
# label augumentation: 557 / 799
# label augumentation: 558 / 799
# label augumentation: 559 / 799
# label augumentation: 560 / 799
# label augumentation: 561 / 799
# label augumentation: 562 / 799
# label augumentation: 563 / 799
# label augumentation: 564 / 799
# label augumentation: 565 / 799
# label augumentation: 566 / 799
# label augumentation: 567 / 799
# label augumentation: 568 / 799
# label augumentation: 569 / 799
# label augumentation: 570 / 799
# label augumentation: 571 / 799
# label augumentation: 572 / 799
# label augumentation: 573 / 799
# label augumentation: 574 / 799
# label augumentation: 575 / 799
# label augumentation: 576 / 799
# label augumentation: 577 / 799
# label augumentation: 578 / 799
# label augumentation: 579 / 799
# label augumentation: 580 / 799
# label augumentation: 581 / 799
# label augumentation: 582 / 799
# label augumentation: 583 / 799
# label augumentation: 584 / 799
# label augumentation: 585 / 799
# label augumentation: 586 / 799
# label augumentation: 587 / 799
# label augumentation: 588 / 799
# label augumentation: 589 / 799
# label augumentation: 590 / 799
# label augumentation: 591 / 799
# label augumentation: 592 / 799
# label augumentation: 593 / 799
# label augumentation: 594 / 799
# label augumentation: 595 / 799
# label augumentation: 596 / 799
# label augumentation: 597 / 799
# label augumentation: 598 / 799
# label augumentation: 599 / 799
# label augumentation: 600 / 799
# label augumentation: 601 / 799
# label augumentation: 602 / 799
# label augumentation: 603 / 799
# label augumentation: 604 / 799
# label augumentation: 605 / 799
# label augumentation: 606 / 799
# label augumentation: 607 / 799
# label augumentation: 608 / 799
# label augumentation: 609 / 799
# label augumentation: 610 / 799
# label augumentation: 611 / 799
# label augumentation: 612 / 799
# label augumentation: 613 / 799
# label augumentation: 614 / 799
# label augumentation: 615 / 799
# label augumentation: 616 / 799
# label augumentation: 617 / 799
# label augumentation: 618 / 799
# label augumentation: 619 / 799
# label augumentation: 620 / 799
# label augumentation: 621 / 799
# label augumentation: 622 / 799
# label augumentation: 623 / 799
# label augumentation: 624 / 799
# label augumentation: 625 / 799
# label augumentation: 626 / 799
# label augumentation: 627 / 799
# label augumentation: 628 / 799
# label augumentation: 629 / 799
# label augumentation: 630 / 799
# label augumentation: 631 / 799
# label augumentation: 632 / 799
# label augumentation: 633 / 799
# label augumentation: 634 / 799
# label augumentation: 635 / 799
# label augumentation: 636 / 799
# label augumentation: 637 / 799
# label augumentation: 638 / 799
# label augumentation: 639 / 799
# label augumentation: 640 / 799
# label augumentation: 641 / 799
# label augumentation: 642 / 799
# label augumentation: 643 / 799
# label augumentation: 644 / 799
# label augumentation: 645 / 799
# label augumentation: 646 / 799
# label augumentation: 647 / 799
# label augumentation: 648 / 799
# label augumentation: 649 / 799
# label augumentation: 650 / 799
# label augumentation: 651 / 799
# label augumentation: 652 / 799
# label augumentation: 653 / 799
# label augumentation: 654 / 799
# label augumentation: 655 / 799
# label augumentation: 656 / 799
# label augumentation: 657 / 799
# label augumentation: 658 / 799
# label augumentation: 659 / 799
# label augumentation: 660 / 799
# label augumentation: 661 / 799
# label augumentation: 662 / 799
# label augumentation: 663 / 799
# label augumentation: 664 / 799
# label augumentation: 665 / 799
# label augumentation: 666 / 799
# label augumentation: 667 / 799
# label augumentation: 668 / 799
# label augumentation: 669 / 799
# label augumentation: 670 / 799
# label augumentation: 671 / 799
# label augumentation: 672 / 799
# label augumentation: 673 / 799
# label augumentation: 674 / 799
# label augumentation: 675 / 799
# label augumentation: 676 / 799
# label augumentation: 677 / 799
# label augumentation: 678 / 799
# label augumentation: 679 / 799
# label augumentation: 680 / 799
# label augumentation: 681 / 799
# label augumentation: 682 / 799
# label augumentation: 683 / 799
# label augumentation: 684 / 799
# label augumentation: 685 / 799
# label augumentation: 686 / 799
# label augumentation: 687 / 799
# label augumentation: 688 / 799
# label augumentation: 689 / 799
# label augumentation: 690 / 799
# label augumentation: 691 / 799
# label augumentation: 692 / 799
# label augumentation: 693 / 799
# label augumentation: 694 / 799
# label augumentation: 695 / 799
# label augumentation: 696 / 799
# label augumentation: 697 / 799
# label augumentation: 698 / 799
# label augumentation: 699 / 799
# label augumentation: 700 / 799
# label augumentation: 701 / 799
# label augumentation: 702 / 799
# label augumentation: 703 / 799
# label augumentation: 704 / 799
# label augumentation: 705 / 799
# label augumentation: 706 / 799
# label augumentation: 707 / 799
# label augumentation: 708 / 799
# label augumentation: 709 / 799
# label augumentation: 710 / 799
# label augumentation: 711 / 799
# label augumentation: 712 / 799
# label augumentation: 713 / 799
# label augumentation: 714 / 799
# label augumentation: 715 / 799
# label augumentation: 716 / 799
# label augumentation: 717 / 799
# label augumentation: 718 / 799
# label augumentation: 719 / 799
# label augumentation: 720 / 799
# label augumentation: 721 / 799
# label augumentation: 722 / 799
# label augumentation: 723 / 799
# label augumentation: 724 / 799
# label augumentation: 725 / 799
# label augumentation: 726 / 799
# label augumentation: 727 / 799
# label augumentation: 728 / 799
# label augumentation: 729 / 799
# label augumentation: 730 / 799
# label augumentation: 731 / 799
# label augumentation: 732 / 799
# label augumentation: 733 / 799
# label augumentation: 734 / 799
# label augumentation: 735 / 799
# label augumentation: 736 / 799
# label augumentation: 737 / 799
# label augumentation: 738 / 799
# label augumentation: 739 / 799
# label augumentation: 740 / 799
# label augumentation: 741 / 799
# label augumentation: 742 / 799
# label augumentation: 743 / 799
# label augumentation: 744 / 799
# label augumentation: 745 / 799
# label augumentation: 746 / 799
# label augumentation: 747 / 799
# label augumentation: 748 / 799
# label augumentation: 749 / 799
# label augumentation: 750 / 799
# label augumentation: 751 / 799
# label augumentation: 752 / 799
# label augumentation: 753 / 799
# label augumentation: 754 / 799
# label augumentation: 755 / 799
# label augumentation: 756 / 799
# label augumentation: 757 / 799
# label augumentation: 758 / 799
# label augumentation: 759 / 799
# label augumentation: 760 / 799
# label augumentation: 761 / 799
# label augumentation: 762 / 799
# label augumentation: 763 / 799
# label augumentation: 764 / 799
# label augumentation: 765 / 799
# label augumentation: 766 / 799
# label augumentation: 767 / 799
# label augumentation: 768 / 799
# label augumentation: 769 / 799
# label augumentation: 770 / 799
# label augumentation: 771 / 799
# label augumentation: 772 / 799
# label augumentation: 773 / 799
# label augumentation: 774 / 799
# label augumentation: 775 / 799
# label augumentation: 776 / 799
# label augumentation: 777 / 799
# label augumentation: 778 / 799
# label augumentation: 779 / 799
# label augumentation: 780 / 799
# label augumentation: 781 / 799
# label augumentation: 782 / 799
# label augumentation: 783 / 799
# label augumentation: 784 / 799
# label augumentation: 785 / 799
# label augumentation: 786 / 799
# label augumentation: 787 / 799
# label augumentation: 788 / 799
# label augumentation: 789 / 799
# label augumentation: 790 / 799
# label augumentation: 791 / 799
# label augumentation: 792 / 799
# label augumentation: 793 / 799
# label augumentation: 794 / 799
# label augumentation: 795 / 799
# label augumentation: 796 / 799
# label augumentation: 797 / 799
# label augumentation: 798 / 799
# label augumentation: 799 / 799
# Images augumentation finished!

# %% [markdown]
# # TRAINING THE MODEL

# %% [markdown]
# The model is designed for image segmentation, which involves partitioning an image into meaningful segments, such as identifying different objects or regions within an image. The CSM class uses a multi-stage approach to refine the segmentation masks progressively. The network's architecture, with multiple stages and feature concatenations, allows it to capture various levels of detail and improve the segmentation results iteratively.

# %%
class HcDataset(Dataset):
    """
    Create dataset for model training
    """

    def __init__(self, input_folder, label_folder, input_size=[192, 128]):

        self.input_w = int(input_size[0])
        self.input_h = int(input_size[1])

        self.label1_w = int(self.input_w / 8)
        self.label1_h = int(self.input_h / 8)

        self.label2_w = int(self.input_w / 4)
        self.label2_h = int(self.input_h / 4)

        self.input_list = os.listdir(input_folder)

        self.input_folder = input_folder
        self.label_folder = label_folder

        self.dataset_L = len(self.input_list)

    def __len__(self):
        return self.dataset_L

    def __getitem__(self, idx):

        input_name = self.input_list[idx]
        label_name = input_name[:-4] + '_Annotation.png'

        input_file_path = self.input_folder + input_name
        label_file_path = self.label_folder + label_name

        img = cv2.imread(input_file_path,0)
        label = cv2.imread(label_file_path,0)

        # Resize images and labels
        img = cv2.resize(img, (self.input_w, self.input_h), interpolation=cv2.INTER_AREA)
        label1 = cv2.resize(label,(self.label1_w, self.label1_h),interpolation=cv2.INTER_AREA)
        label2 = cv2.resize(label,(self.label2_w, self.label2_h),interpolation=cv2.INTER_AREA)

        img = img / 255
        label1 = label1 / 255
        label2 = label2 / 255

        img = img.astype('float32')
        label1 = label1.astype('float32')
        label2 = label2.astype('float32')

        input = torch.from_numpy(img)
        label1 = torch.from_numpy(label1)
        label2 = torch.from_numpy(label2)

        input = input.unsqueeze(0)
        label1 = label1.unsqueeze(0)
        label2 = label2.unsqueeze(0)

        return input, label1,label2

# %%
class CSM(nn.Module):
    """
    Convolutional segmentation machine.
    """

    def __init__(self):
        super(CSM,self).__init__()
        self.stage1 = nn.Sequential(nn.Conv2d(1, 8, 9, padding=4),
                                   nn.BatchNorm2d(8),
                                   nn.ReLU(True),
                                   nn.MaxPool2d(2),
                                   nn.Conv2d(8, 8, 9, padding=4, groups=8),
                                   nn.Conv2d(8, 16, 1),
                                   nn.BatchNorm2d(16),
                                   nn.ReLU(True),
                                   nn.MaxPool2d(2),
                                   nn.Conv2d(16, 16, 9, padding=4, groups=16),
                                   nn.Conv2d(16, 32, 1),
                                   nn.BatchNorm2d(32),
                                   nn.ReLU(True),
                                   nn.MaxPool2d(2),
                                   nn.Conv2d(32, 32, 5, padding=2, groups=32),
                                   nn.Conv2d(32, 64, 1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(True),
                                   nn.Conv2d(64, 64, 9, padding=4, groups=64),
                                   nn.Conv2d(64, 32, 1),
                                   nn.BatchNorm2d(32),
                                   nn.ReLU(True),
                                   nn.Conv2d(32, 16, 1),
                                   nn.ReLU(True),
                                   nn.Conv2d(16, 1, 1),
                                   nn.Sigmoid())

        self.f1 = nn.Sequential(nn.Conv2d(1, 8, 9, padding=4),
                                nn.BatchNorm2d(8),
                                nn.ReLU(True),
                                nn.MaxPool2d(2),
                                nn.Conv2d(8, 16, 9, padding=4),
                                nn.BatchNorm2d(16),
                                nn.ReLU(True),
                                nn.MaxPool2d(2),
                                nn.Conv2d(16, 32, 9, padding=4),
                                nn.BatchNorm2d(32),
                                nn.ReLU(True))

        self.f2 = nn.Sequential(nn.MaxPool2d(2),
                                  nn.Conv2d(32, 16, 5, padding=2),
                                  nn.BatchNorm2d(16),
                                  nn.ReLU(True))

        self.up = nn.UpsamplingBilinear2d(scale_factor=2)

        self.f3 = nn.Sequential(nn.Conv2d(32, 16, 3, padding=1),
                                  nn.BatchNorm2d(16),
                                  nn.ReLU(True),
                                  nn.Conv2d(16, 16, 3, padding=1),
                                  nn.BatchNorm2d(16),
                                  nn.ReLU(True))

        self.stage2 = CSM_stagen()
        self.stage3 = CSM_stagen()

    def forward(self,x):
        y1 = self.stage1(x)
        x_f1 = self.f1(x)

        x_f2 = self.f2(x_f1)
        x_f3 = self.f3(x_f1)

        x1 = torch.cat([y1,x_f2],1)
        y2 = self.stage2(x1)
        y2_up = self.up(y2)
        x2 = torch.cat([y2_up,x_f3],1)
        y3 = self.stage3(x2)

        return y1, y2, y3

# %%
class CSM_stagen(nn.Module):
    """
    Network of n(n>=2) stage in CSM.
    """
    def __init__(self):
        super(CSM_stagen,self).__init__()
        self.conv = nn.Sequential(nn.Conv2d(17, 17, 11, padding=5,groups=17),
                                  nn.Conv2d(17, 32, 1),
                                  nn.BatchNorm2d(32),
                                  nn.ReLU(True),
                                  nn.Conv2d(32, 32, 11, padding=5, groups=32),
                                  nn.Conv2d(32, 64, 1),
                                  nn.BatchNorm2d(64),
                                  nn.ReLU(True),
                                  nn.Conv2d(64, 64, 11, padding=5, groups=64),
                                  nn.Conv2d(64, 32, 1),
                                  nn.BatchNorm2d(32),
                                  nn.ReLU(True),
                                  nn.Conv2d(32, 16, 1),
                                  nn.BatchNorm2d(16),
                                  nn.ReLU(True),
                                  nn.Conv2d(16, 1, 1),
                                  nn.Sigmoid())

    def forward(self,x):
        x = self.conv(x)

        return x

# %%
def train_model(model, dataloader, epoches=20, lr=0.001, device='cuda', save_model_name='models/trained_model.pth'):
    """
    Train the deep model and save result.
    """

    model.to(device)
    print("Using {} device".format(device))

    # Loss function and optimization methods
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # Train
    time_start = time.time()
    for epoch in range(epoches):
        running_loss = 0.0
        for data in dataloader:
            inputs, label1, label2 = data[0].to(device), data[1].to(device), data[2].to(device)
            optimizer.zero_grad()
            pre1, pre2, outputs = model(inputs)

            loss1 = criterion(pre1, label1)
            loss2 = criterion(pre2, label1)
            loss3 = criterion(outputs, label2)
            loss = loss1 + loss2 + loss3
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        print("This is epoch %d / %d" % ((epoch + 1), epoches))
        print(" running loss : %f" % running_loss)
    print("Finished training !")

    # Save model
    if save_model_name[-4:] != '.pth':
        save_model_name = save_model_name + '.pth'
    torch.save(model.state_dict(), save_model_name)
    time_end = time.time()
    print("Time cost: %f s" % (time_end - time_start))

# %%
from torch.utils.data import DataLoader

input_folder = '/kaggle/working/data/train/augu_images/'
label_folder = '/kaggle/working/data/train/augu_labels/'

#  Training data
train_data = HcDataset(input_folder,label_folder,[192,128])
dataloader = DataLoader(dataset=train_data, batch_size=32, shuffle=True)

# %%
# CSM model
net = CSM()

# %%
# File to save the trained model
os.makedirs('/kaggle/working/models/')
save_model_name='/kaggle/working/models/test_model.pth'

# %%
# Model training
train_model(model=net,dataloader=dataloader,epoches=20,lr=0.001,device='cuda',save_model_name=save_model_name)
# Out:
# Using cuda device
# This is epoch 1 / 20
#  running loss : 3.253197
# This is epoch 2 / 20
#  running loss : 3.101781
# This is epoch 3 / 20
#  running loss : 2.813345
# This is epoch 4 / 20
#  running loss : 2.736699
# This is epoch 5 / 20
#  running loss : 2.686211
# This is epoch 6 / 20
#  running loss : 2.632642
# This is epoch 7 / 20
#  running loss : 2.473922
# This is epoch 8 / 20
#  running loss : 2.511789
# This is epoch 9 / 20
#  running loss : 2.361507
# This is epoch 10 / 20
#  running loss : 2.277908
# This is epoch 11 / 20
#  running loss : 2.243339
# This is epoch 12 / 20
#  running loss : 2.195132
# This is epoch 13 / 20
#  running loss : 2.155188
# This is epoch 14 / 20
#  running loss : 2.075538
# This is epoch 15 / 20
#  running loss : 2.099909
# This is epoch 16 / 20
#  running loss : 2.061723
# This is epoch 17 / 20
#  running loss : 1.975272
# This is epoch 18 / 20
#  running loss : 1.970295
# This is epoch 19 / 20
#  running loss : 1.906996
# This is epoch 20 / 20
#  running loss : 1.855852
# Finished training !
# Time cost: 1302.101149 s

# %% [markdown]
# # PREDICTION

# %%
def predict(model, input_folder, predict_folder,device="cpu"):
    """
    Predict using the trained model and save results.
    """

    model.to(device)
    print("Using {} device".format(device))
    model.eval()

    # Resize factor
    k1 = 4
    w = int(768 / k1)
    h = int(512 / k1)

    # Predict
    dirs = os.listdir(input_folder)
    time_start = time.time()
    for i in range(len(dirs)):
        print('Predicting: Image = %d / %d' % (i + 1, len(dirs)))
        img_name = dirs[i]
        predict_name = img_name
        img_path = input_folder + img_name

        img = cv2.imread(img_path, 0)

        # Resize images
        input_img = cv2.resize(img, (w, h), interpolation=cv2.INTER_AREA)
        input_img = input_img.astype('float32')
        input_img = input_img / 255.0

        # To torch.tensor
        input_img = torch.from_numpy(input_img)
        input_img = input_img.unsqueeze(0)
        input_img = input_img.unsqueeze(0)

        input_img = input_img.to(device)

        # Predcit
        _, _, predict = model(input_img)
        predict = predict[0, 0, :, :]
        predict = predict.cpu().detach().numpy()
        predict = np.round(predict)

        # Save
        predict = predict * 255
        predict = predict.astype('uint8')

        predict_path = predict_folder + predict_name

        cv2.imwrite(predict_path, predict)

    # Time consumed
    time_end = time.time()
    print('Finish prediction!')
    print('Time consume: %f' % (time_end - time_start))

# %%
input_folder = '/kaggle/working/data/validation/images/'

# Prediction folder for results saving
predict_folder = '/kaggle/working/results/predictions/'
if os.path.isdir(predict_folder):
    shutil.rmtree(predict_folder)
os.makedirs(predict_folder)

# Load the network
net_dict_file = '/kaggle/working/models/test_model.pth'
net = CSM()
net.load_state_dict(torch.load(net_dict_file))

# Predict
predict(net,input_folder,predict_folder,device='cuda')
# Out:
# Using cuda device
# Predicting: Image = 1 / 200
# Predicting: Image = 2 / 200
# Predicting: Image = 3 / 200
# Predicting: Image = 4 / 200
# Predicting: Image = 5 / 200
# Predicting: Image = 6 / 200
# Predicting: Image = 7 / 200
# Predicting: Image = 8 / 200
# Predicting: Image = 9 / 200
# Predicting: Image = 10 / 200
# Predicting: Image = 11 / 200
# Predicting: Image = 12 / 200
# Predicting: Image = 13 / 200
# Predicting: Image = 14 / 200
# Predicting: Image = 15 / 200
# Predicting: Image = 16 / 200
# Predicting: Image = 17 / 200
# Predicting: Image = 18 / 200
# Predicting: Image = 19 / 200
# Predicting: Image = 20 / 200
# Predicting: Image = 21 / 200
# Predicting: Image = 22 / 200
# Predicting: Image = 23 / 200
# Predicting: Image = 24 / 200
# Predicting: Image = 25 / 200
# Predicting: Image = 26 / 200
# Predicting: Image = 27 / 200
# Predicting: Image = 28 / 200
# Predicting: Image = 29 / 200
# Predicting: Image = 30 / 200
# Predicting: Image = 31 / 200
# Predicting: Image = 32 / 200
# Predicting: Image = 33 / 200
# Predicting: Image = 34 / 200
# Predicting: Image = 35 / 200
# Predicting: Image = 36 / 200
# Predicting: Image = 37 / 200
# Predicting: Image = 38 / 200
# Predicting: Image = 39 / 200
# Predicting: Image = 40 / 200
# Predicting: Image = 41 / 200
# Predicting: Image = 42 / 200
# Predicting: Image = 43 / 200
# Predicting: Image = 44 / 200
# Predicting: Image = 45 / 200
# Predicting: Image = 46 / 200
# Predicting: Image = 47 / 200
# Predicting: Image = 48 / 200
# Predicting: Image = 49 / 200
# Predicting: Image = 50 / 200
# Predicting: Image = 51 / 200
# Predicting: Image = 52 / 200
# Predicting: Image = 53 / 200
# Predicting: Image = 54 / 200
# Predicting: Image = 55 / 200
# Predicting: Image = 56 / 200
# Predicting: Image = 57 / 200
# Predicting: Image = 58 / 200
# Predicting: Image = 59 / 200
# Predicting: Image = 60 / 200
# Predicting: Image = 61 / 200
# Predicting: Image = 62 / 200
# Predicting: Image = 63 / 200
# Predicting: Image = 64 / 200
# Predicting: Image = 65 / 200
# Predicting: Image = 66 / 200
# Predicting: Image = 67 / 200
# Predicting: Image = 68 / 200
# Predicting: Image = 69 / 200
# Predicting: Image = 70 / 200
# Predicting: Image = 71 / 200
# Predicting: Image = 72 / 200
# Predicting: Image = 73 / 200
# Predicting: Image = 74 / 200
# Predicting: Image = 75 / 200
# Predicting: Image = 76 / 200
# Predicting: Image = 77 / 200
# Predicting: Image = 78 / 200
# Predicting: Image = 79 / 200
# Predicting: Image = 80 / 200
# Predicting: Image = 81 / 200
# Predicting: Image = 82 / 200
# Predicting: Image = 83 / 200
# Predicting: Image = 84 / 200
# Predicting: Image = 85 / 200
# Predicting: Image = 86 / 200
# Predicting: Image = 87 / 200
# Predicting: Image = 88 / 200
# Predicting: Image = 89 / 200
# Predicting: Image = 90 / 200
# Predicting: Image = 91 / 200
# Predicting: Image = 92 / 200
# Predicting: Image = 93 / 200
# Predicting: Image = 94 / 200
# Predicting: Image = 95 / 200
# Predicting: Image = 96 / 200
# Predicting: Image = 97 / 200
# Predicting: Image = 98 / 200
# Predicting: Image = 99 / 200
# Predicting: Image = 100 / 200
# Predicting: Image = 101 / 200
# Predicting: Image = 102 / 200
# Predicting: Image = 103 / 200
# Predicting: Image = 104 / 200
# Predicting: Image = 105 / 200
# Predicting: Image = 106 / 200
# Predicting: Image = 107 / 200
# Predicting: Image = 108 / 200
# Predicting: Image = 109 / 200
# Predicting: Image = 110 / 200
# Predicting: Image = 111 / 200
# Predicting: Image = 112 / 200
# Predicting: Image = 113 / 200
# Predicting: Image = 114 / 200
# Predicting: Image = 115 / 200
# Predicting: Image = 116 / 200
# Predicting: Image = 117 / 200
# Predicting: Image = 118 / 200
# Predicting: Image = 119 / 200
# Predicting: Image = 120 / 200
# Predicting: Image = 121 / 200
# Predicting: Image = 122 / 200
# Predicting: Image = 123 / 200
# Predicting: Image = 124 / 200
# Predicting: Image = 125 / 200
# Predicting: Image = 126 / 200
# Predicting: Image = 127 / 200
# Predicting: Image = 128 / 200
# Predicting: Image = 129 / 200
# Predicting: Image = 130 / 200
# Predicting: Image = 131 / 200
# Predicting: Image = 132 / 200
# Predicting: Image = 133 / 200
# Predicting: Image = 134 / 200
# Predicting: Image = 135 / 200
# Predicting: Image = 136 / 200
# Predicting: Image = 137 / 200
# Predicting: Image = 138 / 200
# Predicting: Image = 139 / 200
# Predicting: Image = 140 / 200
# Predicting: Image = 141 / 200
# Predicting: Image = 142 / 200
# Predicting: Image = 143 / 200
# Predicting: Image = 144 / 200
# Predicting: Image = 145 / 200
# Predicting: Image = 146 / 200
# Predicting: Image = 147 / 200
# Predicting: Image = 148 / 200
# Predicting: Image = 149 / 200
# Predicting: Image = 150 / 200
# Predicting: Image = 151 / 200
# Predicting: Image = 152 / 200
# Predicting: Image = 153 / 200
# Predicting: Image = 154 / 200
# Predicting: Image = 155 / 200
# Predicting: Image = 156 / 200
# Predicting: Image = 157 / 200
# Predicting: Image = 158 / 200
# Predicting: Image = 159 / 200
# Predicting: Image = 160 / 200
# Predicting: Image = 161 / 200
# Predicting: Image = 162 / 200
# Predicting: Image = 163 / 200
# Predicting: Image = 164 / 200
# Predicting: Image = 165 / 200
# Predicting: Image = 166 / 200
# Predicting: Image = 167 / 200
# Predicting: Image = 168 / 200
# Predicting: Image = 169 / 200
# Predicting: Image = 170 / 200
# Predicting: Image = 171 / 200
# Predicting: Image = 172 / 200
# Predicting: Image = 173 / 200
# Predicting: Image = 174 / 200
# Predicting: Image = 175 / 200
# Predicting: Image = 176 / 200
# Predicting: Image = 177 / 200
# Predicting: Image = 178 / 200
# Predicting: Image = 179 / 200
# Predicting: Image = 180 / 200
# Predicting: Image = 181 / 200
# Predicting: Image = 182 / 200
# Predicting: Image = 183 / 200
# Predicting: Image = 184 / 200
# Predicting: Image = 185 / 200
# Predicting: Image = 186 / 200
# Predicting: Image = 187 / 200
# Predicting: Image = 188 / 200
# Predicting: Image = 189 / 200
# Predicting: Image = 190 / 200
# Predicting: Image = 191 / 200
# Predicting: Image = 192 / 200
# Predicting: Image = 193 / 200
# Predicting: Image = 194 / 200
# Predicting: Image = 195 / 200
# Predicting: Image = 196 / 200
# Predicting: Image = 197 / 200
# Predicting: Image = 198 / 200
# Predicting: Image = 199 / 200
# Predicting: Image = 200 / 200
# Finish prediction!
# Time consume: 1.579953

# %% [markdown]
# # POSTPROCESSING

# %%
def mcc_edge(in_img):
    """
    Extract max connected component and then extract edge.
    """

    img = in_img
    if in_img.dtype != 'uint8':
        in_img = in_img * 255
        img = in_img.astype('uint8')

    # Max connected component extraction
    retval, labels, stats, centroids = cv2.connectedComponentsWithStats(img, connectivity=4)
    sort_label = np.argsort(-stats[:, 4], )

    idx = labels == sort_label[1]
    max_connect = idx * 255
    max_connect = max_connect.astype('uint8')

    # Edge detection
    edge_img = cv2.Canny(max_connect, 50, 250)

    return edge_img

# %%
def ellip_fit(in_img):
    """
    To fit the fetal head contour into an ellipse, output 5 ellipse parameters.
    Note: The unit of parameters obtained is pixel distance, and the coordinate system is as follows:
    the upper left corner of the image is the origin,vertically downward is the X-axis direction,
    horizontally right is the Y-axis direction.
    """

    edge_img = in_img
    if in_img.dtype != 'uint8':
        in_img = in_img * 255
        edge_img = in_img.astype('uint8')

    # Get coordinates of edge points
    edge_points = np.where(edge_img == 255)
    edge_x = edge_points[0]
    edge_y = edge_points[1]
    edge_x = edge_x.reshape(-1, 1)  # (N, 1)
    edge_y = edge_y.reshape(-1, 1)  # (N, 1)

    # least squares fitting
    x2 = edge_x * edge_x
    xy = 2 * edge_x * edge_y
    _2x = -2 * edge_x
    _2y = -2 * edge_y
    mine_1 = -np.ones(edge_x.shape)
    X = np.concatenate((x2, xy, _2x, _2y, mine_1), axis=1)
    y = -edge_y * edge_y


    model = LinearRegression(fit_intercept=False)
    model.fit(X, y)
    k1 = model.coef_[0, 0]
    k2 = model.coef_[0, 1]
    k3 = model.coef_[0, 2]
    k4 = model.coef_[0, 3]
    k5 = model.coef_[0, 4]

    # Calculate parameters: xc,yc,theta,a,b
    xc = (k3 - k2 * k4) / (k1 - k2 * k2)
    yc = (k1 * k4 - k2 * k3) / (k1 - k2 * k2)
    theta = 0.5 * np.arctan(2 * k2 / (k1 - 1))


    T = np.tan(theta)
    K = (1 - k1 * T * T) / (k1 - T * T)                         # a^2 = K * b^2
    p1 = -np.square(xc + T * yc)
    p2 = -np.square(xc * T - yc)
    b_2 = (k5 * (T * T + K) - p1 - p2 * K) / (K * (T * T + 1))  # b^2
    a_2 = K * b_2                                               # a^2

    a = np.sqrt(a_2)
    b = np.sqrt(b_2)

    # Set a to the long half axis and b to the short half axis, and adjust the angle
    if a < b:
        t = b
        b = a
        a = t
        theta = theta + 0.5 * np.pi

    return xc,yc,theta,a,b

# %%
# Folder of model predictions
input_folder = '/kaggle/working/results/predictions/'

#  Folder to save postprocess results
edge_folder = '/kaggle/working/results/predictions_edge/'
if os.path.isdir(edge_folder):
    shutil.rmtree(edge_folder)
os.makedirs(edge_folder)

# Extract fetal contour
dirs = os.listdir(input_folder)
for i in range(len(dirs)):
    print('Extracting max connect component edge: Image = %d / %d' % (i + 1, len(dirs)))
    img_name = dirs[i]
    img_path = input_folder + img_name

    img = cv2.imread(img_path, 0)
    edge_img = mcc_edge(img)

    save_path = edge_folder + img_name
    cv2.imwrite(save_path, edge_img)
# Out:
# Extracting max connect component edge: Image = 1 / 200
# Extracting max connect component edge: Image = 2 / 200
# Extracting max connect component edge: Image = 3 / 200
# Extracting max connect component edge: Image = 4 / 200
# Extracting max connect component edge: Image = 5 / 200
# Extracting max connect component edge: Image = 6 / 200
# Extracting max connect component edge: Image = 7 / 200
# Extracting max connect component edge: Image = 8 / 200
# Extracting max connect component edge: Image = 9 / 200
# Extracting max connect component edge: Image = 10 / 200
# Extracting max connect component edge: Image = 11 / 200
# Extracting max connect component edge: Image = 12 / 200
# Extracting max connect component edge: Image = 13 / 200
# Extracting max connect component edge: Image = 14 / 200
# Extracting max connect component edge: Image = 15 / 200
# Extracting max connect component edge: Image = 16 / 200
# Extracting max connect component edge: Image = 17 / 200
# Extracting max connect component edge: Image = 18 / 200
# Extracting max connect component edge: Image = 19 / 200
# Extracting max connect component edge: Image = 20 / 200
# Extracting max connect component edge: Image = 21 / 200
# Extracting max connect component edge: Image = 22 / 200
# Extracting max connect component edge: Image = 23 / 200
# Extracting max connect component edge: Image = 24 / 200
# Extracting max connect component edge: Image = 25 / 200
# Extracting max connect component edge: Image = 26 / 200
# Extracting max connect component edge: Image = 27 / 200
# Extracting max connect component edge: Image = 28 / 200
# Extracting max connect component edge: Image = 29 / 200
# Extracting max connect component edge: Image = 30 / 200
# Extracting max connect component edge: Image = 31 / 200
# Extracting max connect component edge: Image = 32 / 200
# Extracting max connect component edge: Image = 33 / 200
# Extracting max connect component edge: Image = 34 / 200
# Extracting max connect component edge: Image = 35 / 200
# Extracting max connect component edge: Image = 36 / 200
# Extracting max connect component edge: Image = 37 / 200
# Extracting max connect component edge: Image = 38 / 200
# Extracting max connect component edge: Image = 39 / 200
# Extracting max connect component edge: Image = 40 / 200
# Extracting max connect component edge: Image = 41 / 200
# Extracting max connect component edge: Image = 42 / 200
# Extracting max connect component edge: Image = 43 / 200
# Extracting max connect component edge: Image = 44 / 200
# Extracting max connect component edge: Image = 45 / 200
# Extracting max connect component edge: Image = 46 / 200
# Extracting max connect component edge: Image = 47 / 200
# Extracting max connect component edge: Image = 48 / 200
# Extracting max connect component edge: Image = 49 / 200
# Extracting max connect component edge: Image = 50 / 200
# Extracting max connect component edge: Image = 51 / 200
# Extracting max connect component edge: Image = 52 / 200
# Extracting max connect component edge: Image = 53 / 200
# Extracting max connect component edge: Image = 54 / 200
# Extracting max connect component edge: Image = 55 / 200
# Extracting max connect component edge: Image = 56 / 200
# Extracting max connect component edge: Image = 57 / 200
# Extracting max connect component edge: Image = 58 / 200
# Extracting max connect component edge: Image = 59 / 200
# Extracting max connect component edge: Image = 60 / 200
# Extracting max connect component edge: Image = 61 / 200
# Extracting max connect component edge: Image = 62 / 200
# Extracting max connect component edge: Image = 63 / 200
# Extracting max connect component edge: Image = 64 / 200
# Extracting max connect component edge: Image = 65 / 200
# Extracting max connect component edge: Image = 66 / 200
# Extracting max connect component edge: Image = 67 / 200
# Extracting max connect component edge: Image = 68 / 200
# Extracting max connect component edge: Image = 69 / 200
# Extracting max connect component edge: Image = 70 / 200
# Extracting max connect component edge: Image = 71 / 200
# Extracting max connect component edge: Image = 72 / 200
# Extracting max connect component edge: Image = 73 / 200
# Extracting max connect component edge: Image = 74 / 200
# Extracting max connect component edge: Image = 75 / 200
# Extracting max connect component edge: Image = 76 / 200
# Extracting max connect component edge: Image = 77 / 200
# Extracting max connect component edge: Image = 78 / 200
# Extracting max connect component edge: Image = 79 / 200
# Extracting max connect component edge: Image = 80 / 200
# Extracting max connect component edge: Image = 81 / 200
# Extracting max connect component edge: Image = 82 / 200
# Extracting max connect component edge: Image = 83 / 200
# Extracting max connect component edge: Image = 84 / 200
# Extracting max connect component edge: Image = 85 / 200
# Extracting max connect component edge: Image = 86 / 200
# Extracting max connect component edge: Image = 87 / 200
# Extracting max connect component edge: Image = 88 / 200
# Extracting max connect component edge: Image = 89 / 200
# Extracting max connect component edge: Image = 90 / 200
# Extracting max connect component edge: Image = 91 / 200
# Extracting max connect component edge: Image = 92 / 200
# Extracting max connect component edge: Image = 93 / 200
# Extracting max connect component edge: Image = 94 / 200
# Extracting max connect component edge: Image = 95 / 200
# Extracting max connect component edge: Image = 96 / 200
# Extracting max connect component edge: Image = 97 / 200
# Extracting max connect component edge: Image = 98 / 200
# Extracting max connect component edge: Image = 99 / 200
# Extracting max connect component edge: Image = 100 / 200
# Extracting max connect component edge: Image = 101 / 200
# Extracting max connect component edge: Image = 102 / 200
# Extracting max connect component edge: Image = 103 / 200
# Extracting max connect component edge: Image = 104 / 200
# Extracting max connect component edge: Image = 105 / 200
# Extracting max connect component edge: Image = 106 / 200
# Extracting max connect component edge: Image = 107 / 200
# Extracting max connect component edge: Image = 108 / 200
# Extracting max connect component edge: Image = 109 / 200
# Extracting max connect component edge: Image = 110 / 200
# Extracting max connect component edge: Image = 111 / 200
# Extracting max connect component edge: Image = 112 / 200
# Extracting max connect component edge: Image = 113 / 200
# Extracting max connect component edge: Image = 114 / 200
# Extracting max connect component edge: Image = 115 / 200
# Extracting max connect component edge: Image = 116 / 200
# Extracting max connect component edge: Image = 117 / 200
# Extracting max connect component edge: Image = 118 / 200
# Extracting max connect component edge: Image = 119 / 200
# Extracting max connect component edge: Image = 120 / 200
# Extracting max connect component edge: Image = 121 / 200
# Extracting max connect component edge: Image = 122 / 200
# Extracting max connect component edge: Image = 123 / 200
# Extracting max connect component edge: Image = 124 / 200
# Extracting max connect component edge: Image = 125 / 200
# Extracting max connect component edge: Image = 126 / 200
# Extracting max connect component edge: Image = 127 / 200
# Extracting max connect component edge: Image = 128 / 200
# Extracting max connect component edge: Image = 129 / 200
# Extracting max connect component edge: Image = 130 / 200
# Extracting max connect component edge: Image = 131 / 200
# Extracting max connect component edge: Image = 132 / 200
# Extracting max connect component edge: Image = 133 / 200
# Extracting max connect component edge: Image = 134 / 200
# Extracting max connect component edge: Image = 135 / 200
# Extracting max connect component edge: Image = 136 / 200
# Extracting max connect component edge: Image = 137 / 200
# Extracting max connect component edge: Image = 138 / 200
# Extracting max connect component edge: Image = 139 / 200
# Extracting max connect component edge: Image = 140 / 200
# Extracting max connect component edge: Image = 141 / 200
# Extracting max connect component edge: Image = 142 / 200
# Extracting max connect component edge: Image = 143 / 200
# Extracting max connect component edge: Image = 144 / 200
# Extracting max connect component edge: Image = 145 / 200
# Extracting max connect component edge: Image = 146 / 200
# Extracting max connect component edge: Image = 147 / 200
# Extracting max connect component edge: Image = 148 / 200
# Extracting max connect component edge: Image = 149 / 200
# Extracting max connect component edge: Image = 150 / 200
# Extracting max connect component edge: Image = 151 / 200
# Extracting max connect component edge: Image = 152 / 200
# Extracting max connect component edge: Image = 153 / 200
# Extracting max connect component edge: Image = 154 / 200
# Extracting max connect component edge: Image = 155 / 200
# Extracting max connect component edge: Image = 156 / 200
# Extracting max connect component edge: Image = 157 / 200
# Extracting max connect component edge: Image = 158 / 200
# Extracting max connect component edge: Image = 159 / 200
# Extracting max connect component edge: Image = 160 / 200
# Extracting max connect component edge: Image = 161 / 200
# Extracting max connect component edge: Image = 162 / 200
# Extracting max connect component edge: Image = 163 / 200
# Extracting max connect component edge: Image = 164 / 200
# Extracting max connect component edge: Image = 165 / 200
# Extracting max connect component edge: Image = 166 / 200
# Extracting max connect component edge: Image = 167 / 200
# Extracting max connect component edge: Image = 168 / 200
# Extracting max connect component edge: Image = 169 / 200
# Extracting max connect component edge: Image = 170 / 200
# Extracting max connect component edge: Image = 171 / 200
# Extracting max connect component edge: Image = 172 / 200
# Extracting max connect component edge: Image = 173 / 200
# Extracting max connect component edge: Image = 174 / 200
# Extracting max connect component edge: Image = 175 / 200
# Extracting max connect component edge: Image = 176 / 200
# Extracting max connect component edge: Image = 177 / 200
# Extracting max connect component edge: Image = 178 / 200
# Extracting max connect component edge: Image = 179 / 200
# Extracting max connect component edge: Image = 180 / 200
# Extracting max connect component edge: Image = 181 / 200
# Extracting max connect component edge: Image = 182 / 200
# Extracting max connect component edge: Image = 183 / 200
# Extracting max connect component edge: Image = 184 / 200
# Extracting max connect component edge: Image = 185 / 200
# Extracting max connect component edge: Image = 186 / 200
# Extracting max connect component edge: Image = 187 / 200
# Extracting max connect component edge: Image = 188 / 200
# Extracting max connect component edge: Image = 189 / 200
# Extracting max connect component edge: Image = 190 / 200
# Extracting max connect component edge: Image = 191 / 200
# Extracting max connect component edge: Image = 192 / 200
# Extracting max connect component edge: Image = 193 / 200
# Extracting max connect component edge: Image = 194 / 200
# Extracting max connect component edge: Image = 195 / 200
# Extracting max connect component edge: Image = 196 / 200
# Extracting max connect component edge: Image = 197 / 200
# Extracting max connect component edge: Image = 198 / 200
# Extracting max connect component edge: Image = 199 / 200
# Extracting max connect component edge: Image = 200 / 200

# %% [markdown]
# # VISUALISATION

# %%
# Visualization
def draw_ellip(xc,yc,a,b,theta,in_img,color='r'):
    """
    Image visualization by drawing predicted ellipse on original ultrasound image.
    """

    if len(in_img.shape) == 3:
        img = in_img
    else:
        w,h = in_img.shape
        img = np.zeros([w,h,3],in_img.dtype)
        img[:,:,0] = in_img
        img[:,:,1] = in_img
        img[:,:,2] = in_img

    if img.dtype != 'uint8':
        img = img*255
        img = img.astype('uint8')

    # Calculate the elliptic coordinate points
    rng = np.arange(0, 2 * np.pi, 0.001)
    ellipse_x = a * np.sin(rng)
    ellipse_y = b * np.cos(rng)

    # Rotate
    theta = theta
    ellipse_x1 = ellipse_x * np.cos(theta) - ellipse_y * np.sin(theta)
    ellipse_y1 = ellipse_x * np.sin(theta) + ellipse_y * np.cos(theta)

    # Translation
    ellipse_x1 = ellipse_x1 + xc
    ellipse_y1 = ellipse_y1 + yc

    # Round
    ellipse_x1 = ellipse_x1.astype(int)
    ellipse_y1 = ellipse_y1.astype(int)

    ellipse_x1 = ellipse_x1 % w
    ellipse_y1 = ellipse_y1 % h

    # Draw ellipse
    img[ellipse_x1, ellipse_y1, 0] = 0
    img[ellipse_x1, ellipse_y1, 1] = 0
    img[ellipse_x1, ellipse_y1, 2] = 0
    if color=='b':
        img[ellipse_x1,ellipse_y1,0]=255
    elif color=='g':
        img[ellipse_x1,ellipse_y1,1]=255
    elif color=='r':
        img[ellipse_x1,ellipse_y1,2]=255
    else:
        img[ellipse_x1,ellipse_y1,0] = 255
        img[ellipse_x1, ellipse_y1, 1] = 255
        img[ellipse_x1, ellipse_y1, 2] = 255

    return img

# %%
# Postprocess results folder
edge_folder = '/kaggle/working/results/predictions_edge/'

# To save ellipse parameters
results = []
name = ['filename', 'center_x(pixel)', 'center_y(pixel)', 'semi_axes_a(pixel)',
        'semi_axes_b(pixel)', 'HC(pixel)', 'angle(rad)']

# Filename of ellipse parameters file
save_ellip_para_file = '/kaggle/working/results/ellip_params.csv'

# upsample factor
u = 16

# Ellipse fitting to obtain parameters
dirs = os.listdir(edge_folder)
for i in range(len(dirs)):
    print('Ellip fitting: Image = %d / %d' % (i + 1, len(dirs)))
    img_name = dirs[i]
    img_path = edge_folder + img_name

    edge_img = cv2.imread(img_path, 0)
    xc, yc, theta, a, b = ellip_fit(edge_img)

    # Restore to original size with the factor 'u'
    xc = (xc + 0.5) * u - 0.5
    yc = (yc + 0.5) * u - 0.5
    a = a * u
    b = b * u
    hc = 2 * np.pi * b + 4 * (a - b)  # HC

    results.append([img_name, xc, yc, a, b, hc, theta])

# Save
predict_results = pd.DataFrame(columns=name, data=results)
predict_results.to_csv(save_ellip_para_file, index=False)
# Out:
# Ellip fitting: Image = 1 / 200
# Ellip fitting: Image = 2 / 200
# Ellip fitting: Image = 3 / 200
# Ellip fitting: Image = 4 / 200
# Ellip fitting: Image = 5 / 200
# Ellip fitting: Image = 6 / 200
# Ellip fitting: Image = 7 / 200
# Ellip fitting: Image = 8 / 200
# Ellip fitting: Image = 9 / 200
# Ellip fitting: Image = 10 / 200
# Ellip fitting: Image = 11 / 200
# Ellip fitting: Image = 12 / 200
# Ellip fitting: Image = 13 / 200
# Ellip fitting: Image = 14 / 200
# Ellip fitting: Image = 15 / 200
# Ellip fitting: Image = 16 / 200
# Ellip fitting: Image = 17 / 200
# Ellip fitting: Image = 18 / 200
# Ellip fitting: Image = 19 / 200
# Ellip fitting: Image = 20 / 200
# Ellip fitting: Image = 21 / 200
# Ellip fitting: Image = 22 / 200
# Ellip fitting: Image = 23 / 200
# Ellip fitting: Image = 24 / 200
# Ellip fitting: Image = 25 / 200
# Ellip fitting: Image = 26 / 200
# Ellip fitting: Image = 27 / 200
# Ellip fitting: Image = 28 / 200
# Ellip fitting: Image = 29 / 200
# Ellip fitting: Image = 30 / 200
# Ellip fitting: Image = 31 / 200
# Ellip fitting: Image = 32 / 200
# Ellip fitting: Image = 33 / 200
# Ellip fitting: Image = 34 / 200
# Ellip fitting: Image = 35 / 200
# Ellip fitting: Image = 36 / 200
# Ellip fitting: Image = 37 / 200
# Ellip fitting: Image = 38 / 200
# Ellip fitting: Image = 39 / 200
# Ellip fitting: Image = 40 / 200
# Ellip fitting: Image = 41 / 200
# Ellip fitting: Image = 42 / 200
# Ellip fitting: Image = 43 / 200
# Ellip fitting: Image = 44 / 200
# Ellip fitting: Image = 45 / 200
# Ellip fitting: Image = 46 / 200
# Ellip fitting: Image = 47 / 200
# Ellip fitting: Image = 48 / 200
# Ellip fitting: Image = 49 / 200
# Ellip fitting: Image = 50 / 200
# Ellip fitting: Image = 51 / 200
# Ellip fitting: Image = 52 / 200
# Ellip fitting: Image = 53 / 200
# Ellip fitting: Image = 54 / 200
# Ellip fitting: Image = 55 / 200
# Ellip fitting: Image = 56 / 200
# Ellip fitting: Image = 57 / 200
# Ellip fitting: Image = 58 / 200
# Ellip fitting: Image = 59 / 200
# Ellip fitting: Image = 60 / 200
# Ellip fitting: Image = 61 / 200
# Ellip fitting: Image = 62 / 200
# Ellip fitting: Image = 63 / 200
# Ellip fitting: Image = 64 / 200
# Ellip fitting: Image = 65 / 200
# Ellip fitting: Image = 66 / 200
# Ellip fitting: Image = 67 / 200
# Ellip fitting: Image = 68 / 200
# Ellip fitting: Image = 69 / 200
# Ellip fitting: Image = 70 / 200
# Ellip fitting: Image = 71 / 200
# Ellip fitting: Image = 72 / 200
# Ellip fitting: Image = 73 / 200
# Ellip fitting: Image = 74 / 200
# Ellip fitting: Image = 75 / 200
# Ellip fitting: Image = 76 / 200
# Ellip fitting: Image = 77 / 200
# Ellip fitting: Image = 78 / 200
# Ellip fitting: Image = 79 / 200
# Ellip fitting: Image = 80 / 200
# Ellip fitting: Image = 81 / 200
# Ellip fitting: Image = 82 / 200
# Ellip fitting: Image = 83 / 200
# Ellip fitting: Image = 84 / 200
# Ellip fitting: Image = 85 / 200
# Ellip fitting: Image = 86 / 200
# Ellip fitting: Image = 87 / 200
# Ellip fitting: Image = 88 / 200
# Ellip fitting: Image = 89 / 200
# Ellip fitting: Image = 90 / 200
# Ellip fitting: Image = 91 / 200
# Ellip fitting: Image = 92 / 200
# Ellip fitting: Image = 93 / 200
# Ellip fitting: Image = 94 / 200
# Ellip fitting: Image = 95 / 200
# Ellip fitting: Image = 96 / 200
# Ellip fitting: Image = 97 / 200
# Ellip fitting: Image = 98 / 200
# Ellip fitting: Image = 99 / 200
# Ellip fitting: Image = 100 / 200
# Ellip fitting: Image = 101 / 200
# Ellip fitting: Image = 102 / 200
# Ellip fitting: Image = 103 / 200
# Ellip fitting: Image = 104 / 200
# Ellip fitting: Image = 105 / 200
# Ellip fitting: Image = 106 / 200
# Ellip fitting: Image = 107 / 200
# Ellip fitting: Image = 108 / 200
# Ellip fitting: Image = 109 / 200
# Ellip fitting: Image = 110 / 200
# Ellip fitting: Image = 111 / 200
# Ellip fitting: Image = 112 / 200
# Ellip fitting: Image = 113 / 200
# Ellip fitting: Image = 114 / 200
# Ellip fitting: Image = 115 / 200
# Ellip fitting: Image = 116 / 200
# Ellip fitting: Image = 117 / 200
# Ellip fitting: Image = 118 / 200
# Ellip fitting: Image = 119 / 200
# Ellip fitting: Image = 120 / 200
# Ellip fitting: Image = 121 / 200
# Ellip fitting: Image = 122 / 200
# Ellip fitting: Image = 123 / 200
# Ellip fitting: Image = 124 / 200
# Ellip fitting: Image = 125 / 200
# Ellip fitting: Image = 126 / 200
# Ellip fitting: Image = 127 / 200
# Ellip fitting: Image = 128 / 200
# Ellip fitting: Image = 129 / 200
# Ellip fitting: Image = 130 / 200
# Ellip fitting: Image = 131 / 200
# Ellip fitting: Image = 132 / 200
# Ellip fitting: Image = 133 / 200
# Ellip fitting: Image = 134 / 200
# Ellip fitting: Image = 135 / 200
# Ellip fitting: Image = 136 / 200
# Ellip fitting: Image = 137 / 200
# Ellip fitting: Image = 138 / 200
# Ellip fitting: Image = 139 / 200
# Ellip fitting: Image = 140 / 200
# Ellip fitting: Image = 141 / 200
# Ellip fitting: Image = 142 / 200
# Ellip fitting: Image = 143 / 200
# Ellip fitting: Image = 144 / 200
# Ellip fitting: Image = 145 / 200
# Ellip fitting: Image = 146 / 200
# Ellip fitting: Image = 147 / 200
# Ellip fitting: Image = 148 / 200
# Ellip fitting: Image = 149 / 200
# Ellip fitting: Image = 150 / 200
# Ellip fitting: Image = 151 / 200
# Ellip fitting: Image = 152 / 200
# Ellip fitting: Image = 153 / 200
# Ellip fitting: Image = 154 / 200
# Ellip fitting: Image = 155 / 200
# Ellip fitting: Image = 156 / 200
# Ellip fitting: Image = 157 / 200
# Ellip fitting: Image = 158 / 200
# Ellip fitting: Image = 159 / 200
# Ellip fitting: Image = 160 / 200
# Ellip fitting: Image = 161 / 200
# Ellip fitting: Image = 162 / 200
# Ellip fitting: Image = 163 / 200
# Ellip fitting: Image = 164 / 200
# Ellip fitting: Image = 165 / 200
# Ellip fitting: Image = 166 / 200
# Ellip fitting: Image = 167 / 200
# Ellip fitting: Image = 168 / 200
# Ellip fitting: Image = 169 / 200
# Ellip fitting: Image = 170 / 200
# Ellip fitting: Image = 171 / 200
# Ellip fitting: Image = 172 / 200
# Ellip fitting: Image = 173 / 200
# Ellip fitting: Image = 174 / 200
# Ellip fitting: Image = 175 / 200
# Ellip fitting: Image = 176 / 200
# Ellip fitting: Image = 177 / 200
# Ellip fitting: Image = 178 / 200
# Ellip fitting: Image = 179 / 200
# Ellip fitting: Image = 180 / 200
# Ellip fitting: Image = 181 / 200
# Ellip fitting: Image = 182 / 200
# Ellip fitting: Image = 183 / 200
# Ellip fitting: Image = 184 / 200
# Ellip fitting: Image = 185 / 200
# Ellip fitting: Image = 186 / 200
# Ellip fitting: Image = 187 / 200
# Ellip fitting: Image = 188 / 200
# Ellip fitting: Image = 189 / 200
# Ellip fitting: Image = 190 / 200
# Ellip fitting: Image = 191 / 200
# Ellip fitting: Image = 192 / 200
# Ellip fitting: Image = 193 / 200
# Ellip fitting: Image = 194 / 200
# Ellip fitting: Image = 195 / 200
# Ellip fitting: Image = 196 / 200
# Ellip fitting: Image = 197 / 200
# Ellip fitting: Image = 198 / 200
# Ellip fitting: Image = 199 / 200
# Ellip fitting: Image = 200 / 200

# %%
# Validation images folder
img_folder = '/kaggle/working/data/validation/images/'

# Folder to save visualization results
visual_folder = '/kaggle/working/results/visualizations/'
if os.path.isdir(visual_folder):
    shutil.rmtree(visual_folder)
os.makedirs(visual_folder)

# Prediction ellipse parameters file
predict_ellip_params_file = '/kaggle/working/results/ellip_params.csv'

params_data = pd.read_csv(predict_ellip_params_file)
v = params_data.values

for i in range(len(params_data)):
    print("Image processing: %d / %d" % (i+1, len(params_data)))
    img_name = v[i, 0]
    xc = v[i, 1]
    yc = v[i, 2]
    a = v[i, 3]
    b = v[i, 4]
    theta = v[i, 6]

    img_path = img_folder + img_name
    img = cv2.imread(img_path,0)

    # Draw ellipse on the original image using predicted ellipse parameters
    visual_img = draw_ellip(xc, yc, a, b, theta, img, 'r')

    # Save
    visual_path = visual_folder + img_name
    cv2.imwrite(visual_path, visual_img)
# Out:
# Image processing: 1 / 200
# Image processing: 2 / 200
# Image processing: 3 / 200
# Image processing: 4 / 200
# Image processing: 5 / 200
# Image processing: 6 / 200
# Image processing: 7 / 200
# Image processing: 8 / 200
# Image processing: 9 / 200
# Image processing: 10 / 200
# Image processing: 11 / 200
# Image processing: 12 / 200
# Image processing: 13 / 200
# Image processing: 14 / 200
# Image processing: 15 / 200
# Image processing: 16 / 200
# Image processing: 17 / 200
# Image processing: 18 / 200
# Image processing: 19 / 200
# Image processing: 20 / 200
# Image processing: 21 / 200
# Image processing: 22 / 200
# Image processing: 23 / 200
# Image processing: 24 / 200
# Image processing: 25 / 200
# Image processing: 26 / 200
# Image processing: 27 / 200
# Image processing: 28 / 200
# Image processing: 29 / 200
# Image processing: 30 / 200
# Image processing: 31 / 200
# Image processing: 32 / 200
# Image processing: 33 / 200
# Image processing: 34 / 200
# Image processing: 35 / 200
# Image processing: 36 / 200
# Image processing: 37 / 200
# Image processing: 38 / 200
# Image processing: 39 / 200
# Image processing: 40 / 200
# Image processing: 41 / 200
# Image processing: 42 / 200
# Image processing: 43 / 200
# Image processing: 44 / 200
# Image processing: 45 / 200
# Image processing: 46 / 200
# Image processing: 47 / 200
# Image processing: 48 / 200
# Image processing: 49 / 200
# Image processing: 50 / 200
# Image processing: 51 / 200
# Image processing: 52 / 200
# Image processing: 53 / 200
# Image processing: 54 / 200
# Image processing: 55 / 200
# Image processing: 56 / 200
# Image processing: 57 / 200
# Image processing: 58 / 200
# Image processing: 59 / 200
# Image processing: 60 / 200
# Image processing: 61 / 200
# Image processing: 62 / 200
# Image processing: 63 / 200
# Image processing: 64 / 200
# Image processing: 65 / 200
# Image processing: 66 / 200
# Image processing: 67 / 200
# Image processing: 68 / 200
# Image processing: 69 / 200
# Image processing: 70 / 200
# Image processing: 71 / 200
# Image processing: 72 / 200
# Image processing: 73 / 200
# Image processing: 74 / 200
# Image processing: 75 / 200
# Image processing: 76 / 200
# Image processing: 77 / 200
# Image processing: 78 / 200
# Image processing: 79 / 200
# Image processing: 80 / 200
# Image processing: 81 / 200
# Image processing: 82 / 200
# Image processing: 83 / 200
# Image processing: 84 / 200
# Image processing: 85 / 200
# Image processing: 86 / 200
# Image processing: 87 / 200
# Image processing: 88 / 200
# Image processing: 89 / 200
# Image processing: 90 / 200
# Image processing: 91 / 200
# Image processing: 92 / 200
# Image processing: 93 / 200
# Image processing: 94 / 200
# Image processing: 95 / 200
# Image processing: 96 / 200
# Image processing: 97 / 200
# Image processing: 98 / 200
# Image processing: 99 / 200
# Image processing: 100 / 200
# Image processing: 101 / 200
# Image processing: 102 / 200
# Image processing: 103 / 200
# Image processing: 104 / 200
# Image processing: 105 / 200
# Image processing: 106 / 200
# Image processing: 107 / 200
# Image processing: 108 / 200
# Image processing: 109 / 200
# Image processing: 110 / 200
# Image processing: 111 / 200
# Image processing: 112 / 200
# Image processing: 113 / 200
# Image processing: 114 / 200
# Image processing: 115 / 200
# Image processing: 116 / 200
# Image processing: 117 / 200
# Image processing: 118 / 200
# Image processing: 119 / 200
# Image processing: 120 / 200
# Image processing: 121 / 200
# Image processing: 122 / 200
# Image processing: 123 / 200
# Image processing: 124 / 200
# Image processing: 125 / 200
# Image processing: 126 / 200
# Image processing: 127 / 200
# Image processing: 128 / 200
# Image processing: 129 / 200
# Image processing: 130 / 200
# Image processing: 131 / 200
# Image processing: 132 / 200
# Image processing: 133 / 200
# Image processing: 134 / 200
# Image processing: 135 / 200
# Image processing: 136 / 200
# Image processing: 137 / 200
# Image processing: 138 / 200
# Image processing: 139 / 200
# Image processing: 140 / 200
# Image processing: 141 / 200
# Image processing: 142 / 200
# Image processing: 143 / 200
# Image processing: 144 / 200
# Image processing: 145 / 200
# Image processing: 146 / 200
# Image processing: 147 / 200
# Image processing: 148 / 200
# Image processing: 149 / 200
# Image processing: 150 / 200
# Image processing: 151 / 200
# Image processing: 152 / 200
# Image processing: 153 / 200
# Image processing: 154 / 200
# Image processing: 155 / 200
# Image processing: 156 / 200
# Image processing: 157 / 200
# Image processing: 158 / 200
# Image processing: 159 / 200
# Image processing: 160 / 200
# Image processing: 161 / 200
# Image processing: 162 / 200
# Image processing: 163 / 200
# Image processing: 164 / 200
# Image processing: 165 / 200
# Image processing: 166 / 200
# Image processing: 167 / 200
# Image processing: 168 / 200
# Image processing: 169 / 200
# Image processing: 170 / 200
# Image processing: 171 / 200
# Image processing: 172 / 200
# Image processing: 173 / 200
# Image processing: 174 / 200
# Image processing: 175 / 200
# Image processing: 176 / 200
# Image processing: 177 / 200
# Image processing: 178 / 200
# Image processing: 179 / 200
# Image processing: 180 / 200
# Image processing: 181 / 200
# Image processing: 182 / 200
# Image processing: 183 / 200
# Image processing: 184 / 200
# Image processing: 185 / 200
# Image processing: 186 / 200
# Image processing: 187 / 200
# Image processing: 188 / 200
# Image processing: 189 / 200
# Image processing: 190 / 200
# Image processing: 191 / 200
# Image processing: 192 / 200
# Image processing: 193 / 200
# Image processing: 194 / 200
# Image processing: 195 / 200
# Image processing: 196 / 200
# Image processing: 197 / 200
# Image processing: 198 / 200
# Image processing: 199 / 200
# Image processing: 200 / 200

# %% [markdown]
# # EVALUATION

# %%
def dice(img1, img2):
    """
    Calculate dice coefficient between two images.
    """
    img1 = np.round(img1 / 255).astype('uint8')
    img2 = np.round(img2 / 255).astype('uint8')
    s1 = np.sum(img1)
    s2 = np.sum(img2)
    s = np.sum(cv2.bitwise_and(img1, img2))
    d = 2 * s / (s1 + s2)
    return d

# %%
def dice(img1, img2):
    """
    Calculate dice coefficient between two images.
    """
    img1 = np.round(img1 / 255).astype('uint8')
    img2 = np.round(img2 / 255).astype('uint8')
    s1 = np.sum(img1)
    s2 = np.sum(img2)
    s = np.sum(cv2.bitwise_and(img1, img2))
    d = 2 * s / (s1 + s2)
    return d

def dice_folder(label_folder, predict_folder):
    """
    Calculate dice coefficient in between tow folder.
    """
    dirs = os.listdir(predict_folder)
    D = []
    print('Calculating dice coefficient ...')
    for i in range(len(dirs)):
        predict_name = dirs[i]
        predict_path = predict_folder + predict_name

        label_name = predict_name[:-4] + '_Annotation.png'
        label_path = label_folder + label_name

        label = cv2.imread(label_path, 0)
        predict = cv2.imread(predict_path,0)

        r,c = label.shape
        resize_predict = cv2.resize(predict, (c, r), interpolation=cv2.INTER_CUBIC)
        resize_predict = (np.round(resize_predict / 255) * 255).astype('uint8')

        d = dice(label, resize_predict)
        D.append(d)

    dice_series = pd.Series(D, index=dirs)
    return dice_series

# %%
img_folder = '/kaggle/working/data/validation/images/'

# Folder to save visualization results
visual_folder = '/kaggle/working/results/visualizations/'
if os.path.isdir(visual_folder):
    shutil.rmtree(visual_folder)
os.makedirs(visual_folder)

# Prediction ellipse parameters file
predict_ellip_params_file = '/kaggle/working/results/ellip_params.csv'

params_data = pd.read_csv(predict_ellip_params_file)
v = params_data.values

for i in range(len(params_data)):
    print("Image processing: %d / %d" % (i+1, len(params_data)))
    img_name = v[i, 0]
    xc = v[i, 1]
    yc = v[i, 2]
    a = v[i, 3]
    b = v[i, 4]
    theta = v[i, 6]

    img_path = img_folder + img_name
    img = cv2.imread(img_path,0)

    # Draw ellipse on the original image using predicted ellipse parameters
    visual_img = draw_ellip(xc, yc, a, b, theta, img, 'r')

    # Save
    visual_path = visual_folder + img_name
    cv2.imwrite(visual_path, visual_img)
# Out:
# Image processing: 1 / 200
# Image processing: 2 / 200
# Image processing: 3 / 200
# Image processing: 4 / 200
# Image processing: 5 / 200
# Image processing: 6 / 200
# Image processing: 7 / 200
# Image processing: 8 / 200
# Image processing: 9 / 200
# Image processing: 10 / 200
# Image processing: 11 / 200
# Image processing: 12 / 200
# Image processing: 13 / 200
# Image processing: 14 / 200
# Image processing: 15 / 200
# Image processing: 16 / 200
# Image processing: 17 / 200
# Image processing: 18 / 200
# Image processing: 19 / 200
# Image processing: 20 / 200
# Image processing: 21 / 200
# Image processing: 22 / 200
# Image processing: 23 / 200
# Image processing: 24 / 200
# Image processing: 25 / 200
# Image processing: 26 / 200
# Image processing: 27 / 200
# Image processing: 28 / 200
# Image processing: 29 / 200
# Image processing: 30 / 200
# Image processing: 31 / 200
# Image processing: 32 / 200
# Image processing: 33 / 200
# Image processing: 34 / 200
# Image processing: 35 / 200
# Image processing: 36 / 200
# Image processing: 37 / 200
# Image processing: 38 / 200
# Image processing: 39 / 200
# Image processing: 40 / 200
# Image processing: 41 / 200
# Image processing: 42 / 200
# Image processing: 43 / 200
# Image processing: 44 / 200
# Image processing: 45 / 200
# Image processing: 46 / 200
# Image processing: 47 / 200
# Image processing: 48 / 200
# Image processing: 49 / 200
# Image processing: 50 / 200
# Image processing: 51 / 200
# Image processing: 52 / 200
# Image processing: 53 / 200
# Image processing: 54 / 200
# Image processing: 55 / 200
# Image processing: 56 / 200
# Image processing: 57 / 200
# Image processing: 58 / 200
# Image processing: 59 / 200
# Image processing: 60 / 200
# Image processing: 61 / 200
# Image processing: 62 / 200
# Image processing: 63 / 200
# Image processing: 64 / 200
# Image processing: 65 / 200
# Image processing: 66 / 200
# Image processing: 67 / 200
# Image processing: 68 / 200
# Image processing: 69 / 200
# Image processing: 70 / 200
# Image processing: 71 / 200
# Image processing: 72 / 200
# Image processing: 73 / 200
# Image processing: 74 / 200
# Image processing: 75 / 200
# Image processing: 76 / 200
# Image processing: 77 / 200
# Image processing: 78 / 200
# Image processing: 79 / 200
# Image processing: 80 / 200
# Image processing: 81 / 200
# Image processing: 82 / 200
# Image processing: 83 / 200
# Image processing: 84 / 200
# Image processing: 85 / 200
# Image processing: 86 / 200
# Image processing: 87 / 200
# Image processing: 88 / 200
# Image processing: 89 / 200
# Image processing: 90 / 200
# Image processing: 91 / 200
# Image processing: 92 / 200
# Image processing: 93 / 200
# Image processing: 94 / 200
# Image processing: 95 / 200
# Image processing: 96 / 200
# Image processing: 97 / 200
# Image processing: 98 / 200
# Image processing: 99 / 200
# Image processing: 100 / 200
# Image processing: 101 / 200
# Image processing: 102 / 200
# Image processing: 103 / 200
# Image processing: 104 / 200
# Image processing: 105 / 200
# Image processing: 106 / 200
# Image processing: 107 / 200
# Image processing: 108 / 200
# Image processing: 109 / 200
# Image processing: 110 / 200
# Image processing: 111 / 200
# Image processing: 112 / 200
# Image processing: 113 / 200
# Image processing: 114 / 200
# Image processing: 115 / 200
# Image processing: 116 / 200
# Image processing: 117 / 200
# Image processing: 118 / 200
# Image processing: 119 / 200
# Image processing: 120 / 200
# Image processing: 121 / 200
# Image processing: 122 / 200
# Image processing: 123 / 200
# Image processing: 124 / 200
# Image processing: 125 / 200
# Image processing: 126 / 200
# Image processing: 127 / 200
# Image processing: 128 / 200
# Image processing: 129 / 200
# Image processing: 130 / 200
# Image processing: 131 / 200
# Image processing: 132 / 200
# Image processing: 133 / 200
# Image processing: 134 / 200
# Image processing: 135 / 200
# Image processing: 136 / 200
# Image processing: 137 / 200
# Image processing: 138 / 200
# Image processing: 139 / 200
# Image processing: 140 / 200
# Image processing: 141 / 200
# Image processing: 142 / 200
# Image processing: 143 / 200
# Image processing: 144 / 200
# Image processing: 145 / 200
# Image processing: 146 / 200
# Image processing: 147 / 200
# Image processing: 148 / 200
# Image processing: 149 / 200
# Image processing: 150 / 200
# Image processing: 151 / 200
# Image processing: 152 / 200
# Image processing: 153 / 200
# Image processing: 154 / 200
# Image processing: 155 / 200
# Image processing: 156 / 200
# Image processing: 157 / 200
# Image processing: 158 / 200
# Image processing: 159 / 200
# Image processing: 160 / 200
# Image processing: 161 / 200
# Image processing: 162 / 200
# Image processing: 163 / 200
# Image processing: 164 / 200
# Image processing: 165 / 200
# Image processing: 166 / 200
# Image processing: 167 / 200
# Image processing: 168 / 200
# Image processing: 169 / 200
# Image processing: 170 / 200
# Image processing: 171 / 200
# Image processing: 172 / 200
# Image processing: 173 / 200
# Image processing: 174 / 200
# Image processing: 175 / 200
# Image processing: 176 / 200
# Image processing: 177 / 200
# Image processing: 178 / 200
# Image processing: 179 / 200
# Image processing: 180 / 200
# Image processing: 181 / 200
# Image processing: 182 / 200
# Image processing: 183 / 200
# Image processing: 184 / 200
# Image processing: 185 / 200
# Image processing: 186 / 200
# Image processing: 187 / 200
# Image processing: 188 / 200
# Image processing: 189 / 200
# Image processing: 190 / 200
# Image processing: 191 / 200
# Image processing: 192 / 200
# Image processing: 193 / 200
# Image processing: 194 / 200
# Image processing: 195 / 200
# Image processing: 196 / 200
# Image processing: 197 / 200
# Image processing: 198 / 200
# Image processing: 199 / 200
# Image processing: 200 / 200

# %%
params_label_file = '/kaggle/working/data/validation/val_set_pixel_size_and_HC.csv'
params_predict_file = '/kaggle/working/results/ellip_params.csv'

# %%
# Calculate mean difference and mean abs difference
params_label = pd.read_csv(params_label_file)
params_predict = pd.read_csv(params_predict_file)

label_fn = params_label['filename'].values
label_ps = params_label['pixel size'].values
label_hc = params_label['head circumference (mm)'].values

predict_fn = params_predict['filename'].values
predict_hc = params_predict['HC(pixel)'].values

label_ps_series = pd.Series(label_ps,label_fn)
label_hc_series = pd.Series(label_hc,label_fn)


predict_hc_series = pd.Series(predict_hc,predict_fn)


eval_results = pd.DataFrame({'pixel size(mm)':label_ps_series, 'HC_truth(mm)':label_hc_series,
                             'HC_predict(pixel)': predict_hc_series})

eval_results['HC_predict(mm)'] = eval_results['HC_predict(pixel)'] * eval_results['pixel size(mm)']
eval_results['Difference(mm)'] = eval_results['HC_predict(mm)'] - eval_results['HC_truth(mm)']
eval_results['Abs_Difference(mm)'] = abs(eval_results['Difference(mm)'])

ave_adf = np.average(eval_results['Abs_Difference(mm)'].values)
ave_df = np.average(eval_results['Difference(mm)'].values)

print("Mean difference: %f(mm)" % (ave_df))
print("Mean absolulate difference: %f(mm)" % (ave_adf))
# Out:
# Mean difference: 3.702889(mm)
# Mean absolulate difference: 4.209150(mm)

# %%
label_folder = '/kaggle/working/data/validation/labels/'
predict_folder = '/kaggle/working/results/predictions/'

# %%
# Calculate mean dice cofficience
dice = dice_folder(label_folder,predict_folder)
eval_results['Dice'] = dice
ave_dice = np.average(dice.values)
print('Mean dice: %f' % ave_dice)
# Out:
# Calculating dice coefficient ...
# Mean dice: 0.970637

# %%
import os
import numpy as np
import pandas as pd
import cv2
from scipy.spatial.distance import directed_hausdorff

def hausdorff_folder(label_folder, predict_folder, pixel_size):
    """
    Calculate Hausdorff distance between images in two folders.
    """
    dirs = os.listdir(predict_folder)
    D = []
    print('Calculating Hausdorff distance ...')
    for predict_name in dirs:
        predict_path = os.path.join(predict_folder, predict_name)

        label_name = predict_name[:-4] + '_Annotation.png'
        label_path = os.path.join(label_folder, label_name)

        label = cv2.imread(label_path, 0)
        predict = cv2.imread(predict_path, 0)

        if label is None or predict is None:
            print(f"Error reading {predict_name} or corresponding label.")
            continue

        r, c = label.shape
        resize_predict = cv2.resize(predict, (c, r), interpolation=cv2.INTER_CUBIC)
        resize_predict = (np.round(resize_predict / 255) * 255).astype('uint8')

        d = hausdorff_d(label, resize_predict) * pixel_size[predict_name]
        D.append(d)

    hausdorff_d_series = pd.Series(D, index=dirs)
    return hausdorff_d_series

def hausdorff_d(img1, img2):
    """
    Calculate Hausdorff distance between two images using directed Hausdorff distance.
    """
    def extract_contour_points(img):
        contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        if len(contours) == 0:
            return np.empty((0, 2))
        return np.vstack([contour.squeeze() for contour in contours])

    points1 = extract_contour_points(img1)
    points2 = extract_contour_points(img2)

    d1 = directed_hausdorff(points1, points2)[0]
    d2 = directed_hausdorff(points2, points1)[0]

    return max(d1, d2)

hd = hausdorff_folder(label_folder, predict_folder, label_ps_series)
eval_results = {}
eval_results['Hausdorff distance(mm)'] = hd
ave_hd = np.average(hd.values)
print('Mean Hausdorff distance between predict and label is: %f(mm)' % ave_hd)
# Out:
# Calculating Hausdorff distance ...
# Mean Hausdorff distance between predict and label is: 2.312199(mm)

# %%
import pandas as pd

# Convert the dictionary to a DataFrame
eval_results_df = pd.DataFrame(list(eval_results.items()), columns=['Metric', 'Value'])

# Save the DataFrame to a CSV file
save_path = '/kaggle/working/results/eval_results.csv'
eval_results_df.to_csv(save_path, index=False)

print(f'Evaluation results saved to {save_path}')
# Out:
# Evaluation results saved to /kaggle/working/results/eval_results.csv

# %% [markdown]
# # INTERPRETATION

# %% [markdown]
# - Hausdorff Distance:
# Mean Hausdorff distance between predict and label is: 2.312199 mm
#
# Interpretation: The Hausdorff distance measures the maximum distance between the predicted segmentation boundary and the ground truth boundary. A mean Hausdorff distance of 2.312199 mm indicates that, on average, the furthest point of the predicted segmentation is 2.312199 mm away from the nearest point on the ground truth segmentation. This low value suggests that the predicted segmentations are generally close to the true segmentations.
#
# - Dice Coefficient:
# Mean dice: 0.970637
#
# Interpretation: The Dice coefficient is a measure of overlap between the predicted segmentation and the ground truth segmentation. It ranges from 0 to 1, where 1 indicates perfect overlap. A mean Dice coefficient of 0.970637 indicates a very high degree of overlap, suggesting that the predicted segmentations are highly accurate and closely match the ground truth.
#
# - Mean Difference:
# Mean difference: 3.702889 mm
#
# Interpretation: The mean difference measures the average difference between the predicted and ground truth segmentations. A mean difference of 3.702889 mm suggests that, on average, the predictions differ from the ground truth by 3.702889 mm. While the Hausdorff distance captures the worst-case scenario, the mean difference provides an average measure of accuracy across all points.
#
# - Mean Absolute Difference:
# Mean absolute difference: 4.209150 mm
#
# Interpretation: The mean absolute difference is similar to the mean difference but takes the absolute value of differences, ensuring that all deviations are treated as positive. This metric gives a sense of the average magnitude of errors without considering the direction of the errors. A mean absolute difference of 4.209150 mm indicates that the average size of deviations, irrespective of direction, is 4.209150 mm.
#
# # Overall Interpretation
#
# The evaluation metrics indicate that the model's predictions are very close to the ground truth segmentations:
#
# - The low Hausdorff distance shows that the maximum error in boundary prediction is small.
#
# - The high Dice coefficient indicates a high overlap between predicted and true segmentations.
#
# - The mean difference and mean absolute difference are relatively low, suggesting that the average errors in the predictions are small.
